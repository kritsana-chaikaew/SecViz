# %%
import pandas as pd
import numpy as np
import json
from random import randint
from collections import defaultdict

# %%
DOMESTIC = "2018-07-Domestic-Exchange-Index"
INTER = "2018-07-International-Exchange-Index"

# %%
domestic_data = pd.read_csv(DOMESTIC+".csv", dtype='str')
inter_data = pd.read_csv(INTER+".csv", dtype='str')
inter_data
# Out:
#     ASN-source       ASN                                   Name       Type  \
# 0      AS38566    AS2914                               NTT (SG)  ISP-Inter
# 1       AS4651   AS45758  Triple T Internet/ Triple T Broadband  ISP-Local
# 2       AS4651   AS38450                                    GIN   ISP-Govt
# 3       AS4651   AS18013               B Network Solution (BNS)  ISP-Local
# 4       AS4651    AS9931                                CAT-ISP  ISP-Local
# 5       AS4651  AS131090                             CAT ON Net  ISP-Local
# 6       AS4651    AS4618                                   INET  ISP-Local
# 7       AS4651   AS24187                                   KIRZ  ISP-Local
# 8       AS4651   AS56067                              Metrabyte  ISP-Local
# 9       AS4651   AS38888                                 MILCOM  ISP-Local
# 10      AS4651   AS45328                             NIPA.CLOUD  ISP-Local
# 11      AS4651   AS38566                               NTT (TH)  ISP-Local
# 12      AS4651    AS4765                       Pacific Internet  ISP-Local
# 13      AS4651   AS23884                         PROEN Internet  ISP-Local
# 14      AS4651   AS45413                               ServeNET  ISP-Local
# 15      AS4651    AS5639                               SIAMDATA  ISP-Local
# 16      AS4651   AS23969                                TOT ISP  ISP-Local
# 17      AS4651  AS131293                                TOT LLI  ISP-Local
# 18      AS4651    AS7470              True Internet Corporation  ISP-Local
# 19      AS4651   AS38794                            UIH/ BEENET  ISP-Local
# 20      AS4651   AS38328                                ICT MOF   ISP-Govt
# 21      AS4651    AS4621                                 UniNet   ISP-Govt
# 22      AS4651    AS1200                            AMS-IX (AN)  ISP-Inter
# 23      AS4651   AS19996                      Any2Coresite (US)  ISP-Inter
# 24      AS4651   AS59360                              BBIX (HK)  ISP-Inter
# 25      AS4651   AS59360                              BBIX (SG)  ISP-Inter
# 26      AS4651    AS9505                             CHT-I (TW)  ISP-Inter
# 27      AS4651    AS3462                       CHT-I HiNet (TW)  ISP-Inter
# 28      AS4651    AS6695                            DE-CIX (DE)  ISP-Inter
# 29      AS4651   AS15133                          EdgeCast (SG)  ISP-Inter
# ..         ...       ...                                    ...        ...
# 607    AS24187    AS9505                               CHT (SG)  ISP-Inter
# 608    AS24187    AS2914                               NTT (SG)  ISP-Inter
# 609    AS24187   AS24218                               GTC (MY)  ISP-Inter
# 610     AS4765    AS4628                  Pacific Internet (SG)  ISP-Inter
# 611     AS4765    AS9304                               HGC (HK)  ISP-Inter
# 612    AS56309    AS9304                               HGC (HK)  ISP-Inter
# 613    AS23884   AS45474                        NexusGuard (SG)  ISP-Inter
# 614    AS23884   AS45474                        NexusGuard (HK)  ISP-Inter
# 615    AS24475   AS24490                             TEIN4 (HK)  ISP-Inter
# 616    AS24475   AS17934                            JGN-IX (SG)  ISP-Inter
# 617    AS45758   AS19996                      Any2Coresite (US)  ISP-Inter
# 618    AS45758    AS1273                               C&W (FR)  ISP-Inter
# 619    AS45758    AS9505                               CHT (SG)  ISP-Inter
# 620    AS45758     AS174                            Cogent (FR)  ISP-Inter
# 621    AS45758     AS174                            Cogent (US)  ISP-Inter
# 622    AS45758    AS6695                            DE-CIX (DE)  ISP-Inter
# 623    AS45758   AS24115                       Equinix-SJC (US)  ISP-Inter
# 624    AS45758   AS15412               Global Cloud Xchang (SG)  ISP-Inter
# 625    AS45758    AS3356                                L3 (US)  ISP-Inter
# 626    AS45758    AS8075                         Microsoft (US)  ISP-Inter
# 627    AS45758    AS4436                            nLayer (US)  ISP-Inter
# 628    AS45758    AS2914                               NTT (SG)  ISP-Inter
# 629    AS45758   AS46786                              PAIX (US)  ISP-Inter
# 630    AS45758    AS3491                              PCCW (HK)  ISP-Inter
# 631    AS45758    AS6453                              TATA (US)  ISP-Inter
# 632    AS45758    AS6762                    Telecom Italia (FR)  ISP-Inter
# 633    AS45758    AS1299                        Telesonera (FR)  ISP-Inter
# 634    AS45758    AS7473                           Singtel (SG)  ISP-Inter
# 635    AS38794   AS12076                         Microsoft (SG)  ISP-Inter
# 636    AS38794   AS38895                            Amazon (SG)  ISP-Inter
#
#     Bandwidth   Gb/s        Connectivity Type
# 0         350  Mbps.  Transit/IPv6 Dual Stack
# 1         500   Mbps                     IPv4
# 2           1   Gbps                     IPv4
# 3          10   Mbps                     IPv4
# 4         200   Gbps                     IPv4
# 5         210   Gbps                     IPv4
# 6         1.8   Gbps                     IPv4
# 7         720   Mbps                     IPv4
# 8         101   Mbps                     IPv4
# 9         600   Mbps                     IPv4
# 10        100   Mbps          IPv6 Dual Stack
# 11        380   Mbps          IPv6 Dual Stack
# 12        500   Mbps                  Peering
# 13       1.05   Gbps          IPv6 Dual Stack
# 14         30   Mbps                     IPv4
# 15        200   Mbps                     IPv4
# 16         40   Gbps                     IPv4
# 17         10   Gbps                     IPv4
# 18        140   Gbps                     IPv4
# 19        700   Mbps          IPv6 Dual Stack
# 20        230   Mbps                     IPv4
# 21        100   Gbps                     IPv4
# 22          9   Gbps                  Peering
# 23         10   Gbps                  Peering
# 24         10   Gbps                  Peering
# 25          1   Gbps                  Peering
# 26        155   Mbps                  Peering
# 27        310   Mbps                  Peering
# 28         10   Gbps                  Peering
# 29         20   Gbps                  Peering
# ..        ...    ...                      ...
# 607       300  Mbps.                     IPv4
# 608       800  Mbps.                     IPv4
# 609       200  Mbps.                     IPv4
# 610       0.2   Gbps                  Peering
# 611       0.1   Gbps                  Peering
# 612      0.05   Gbps                  Transit
# 613        10   Gbps                  Peering
# 614        10   Gbps                  Peering
# 615         1   Gbps                  Transit
# 616         1   Gbps                  Transit
# 617         1   Gbps  Peering/IPv6 Dual Stack
# 618         1   Gbps  Transit/IPv6 Dual Stack
# 619         3   Gbps  Transit/IPv6 Dual Stack
# 620         3   Gbps  Transit/IPv6 Dual Stack
# 621         5   Gbps  Transit/IPv6 Dual Stack
# 622        10   Gbps  Peering/IPv6 Dual Stack
# 623        10   Gbps  Peering/IPv6 Dual Stack
# 624         3   Gbps  Transit/IPv6 Dual Stack
# 625         4   Gbps  Transit/IPv6 Dual Stack
# 626        10   Gbps  Peering/IPv6 Dual Stack
# 627         4   Gbps  Transit/IPv6 Dual Stack
# 628         5   Gbps  Transit/IPv6 Dual Stack
# 629        10   Gbps  Peering/IPv6 Dual Stack
# 630       2.5   Gbps  Transit/IPv6 Dual Stack
# 631         2   Gbps  Transit/IPv6 Dual Stack
# 632         1   Gbps  Transit/IPv6 Dual Stack
# 633         2   Gbps  Transit/IPv6 Dual Stack
# 634         4   Gbps  Transit/IPv6 Dual Stack
# 635         2   Gbps                     IPv4
# 636        10   Gbps                     IPv4
#
# [637 rows x 7 columns]

# %%
domestic_names = list(set(domestic_data["Name"].values))
inter_names = list(set(inter_data["Name"].values))

DOMESTIC_NODES = defaultdict(set)
for item in domestic_data[["ASN", "Name"]].values:
    DOMESTIC_NODES[item[0]].add(item[1])
    
INTER_NODES = defaultdict(set)
for item in inter_data[["ASN", "Name"]].values:
    INTER_NODES[item[0]].add(item[1])
for item in inter_data["ASN-source"].values:
    if len(INTER_NODES[item]) == 0:
        INTER_NODES[item].add(item)
        inter_names.append(item)

# %%
DOMESTIC_EDGES = [(list(DOMESTIC_NODES[item[0]])[0], item[1]) for item in domestic_data[["ASN-source", "Name"]].values]

INTER_EDGES = [(list(INTER_NODES[item[0]])[0], item[1]) for item in inter_data[["ASN-source", "Name"]].values]

INTER_EDGES
# Out:
# [('NTT (TH)', 'NTT (SG)'),
#  ('AS4651', 'Triple T Internet/ Triple T Broadband'),
#  ('AS4651', 'GIN'),
#  ('AS4651', 'B Network Solution (BNS)'),
#  ('AS4651', 'CAT-ISP'),
#  ('AS4651', 'CAT ON Net'),
#  ('AS4651', 'INET'),
#  ('AS4651', 'KIRZ'),
#  ('AS4651', 'Metrabyte'),
#  ('AS4651', 'MILCOM'),
#  ('AS4651', 'NIPA.CLOUD'),
#  ('AS4651', 'NTT (TH)'),
#  ('AS4651', 'Pacific Internet'),
#  ('AS4651', 'PROEN Internet'),
#  ('AS4651', 'ServeNET'),
#  ('AS4651', 'SIAMDATA'),
#  ('AS4651', 'TOT ISP'),
#  ('AS4651', 'TOT LLI'),
#  ('AS4651', 'True Internet Corporation'),
#  ('AS4651', 'UIH/ BEENET'),
#  ('AS4651', 'ICT MOF'),
#  ('AS4651', 'UniNet'),
#  ('AS4651', 'AMS-IX (AN)'),
#  ('AS4651', 'Any2Coresite (US)'),
#  ('AS4651', 'BBIX (HK)'),
#  ('AS4651', 'BBIX (SG)'),
#  ('AS4651', 'CHT-I (TW)'),
#  ('AS4651', 'CHT-I HiNet (TW)'),
#  ('AS4651', 'DE-CIX (DE)'),
#  ('AS4651', 'EdgeCast (SG)'),
#  ('AS4651', 'Equinix (FR)'),
#  ('AS4651', 'Equinix (SG)'),
#  ('AS4651', 'Equinix San Jose (US)'),
#  ('AS4651', 'Etisalat (UAE)'),
#  ('AS4651', 'Facebook (SG)'),
#  ('AS4651', 'GlobalNet (MM)'),
#  ('AS4651', 'Google (HK)'),
#  ('AS4651', 'Google (SG)'),
#  ('AS4651', 'HKIX (HK)'),
#  ('AS4651', 'Hurricane (HK)'),
#  ('AS4651', 'Hurricane (US)'),
#  ('AS4651', 'JPNAP (JP)'),
#  ('AS4651', 'KDDI (HK)'),
#  ('AS4651', 'Cogent (SG)'),
#  ('AS4651', 'Level3 (US)'),
#  ('AS4651', 'LG DACOM (KR)'),
#  ('AS4651', 'LINX (UK)'),
#  ('AS4651', 'Microsoft (HK)'),
#  ('AS4651', 'Microsoft (US)'),
#  ('AS4651', 'MPT (MM)'),
#  ('AS4651', 'Netflix (SG)'),
#  ('AS4651', 'NLIX (NL)'),
#  ('AS4651', 'NTT (HK)'),
#  ('AS4651', 'NTT (SG)'),
#  ('AS4651', 'PCCW (HK)'),
#  ('AS4651', 'PLDT (PH)\xa0'),
#  ('AS4651', 'SingTel (SG)'),
#  ('AS4651', 'Sky Telecom (LA)'),
#  ('AS4651', 'SOFTBANK (HK)'),
#  ('AS4651', 'StarHub (SG)\xa0'),
#  ('AS4651', 'TATA\xa0\xa0(IN)'),
#  ('AS4651', 'TATA (SG)'),
#  ('AS4651', 'TATA (US)'),
#  ('AS4651', 'TeliaSonera (HK)'),
#  ('AS4651', 'TeliaSonera (SG)'),
#  ('AS4651', 'Telstra (HK)\xa0'),
#  ('AS4651', 'Telstra (SG)'),
#  ('AS4651', 'TM (MY)\xa0'),
#  ('AS4651', 'Twitch (SG)'),
#  ('AS4651', 'VNPT Corp (VN)'),
#  ('AS4651', 'Vodafone (FR)\xa0'),
#  ('BB Connect-IIG', 'INFONET'),
#  ('BB Connect-IIG', 'DTAC (IIG)'),
#  ('BB Connect-IIG', 'UIH (Beenet)'),
#  ('BB Connect-IIG', 'ICT MOF'),
#  ('BB Connect-IIG', '1-Net (SG)'),
#  ('BB Connect-IIG', 'Akamai (SG)'),
#  ('BB Connect-IIG', 'Alibaba (SG)'),
#  ('BB Connect-IIG', 'Amazon (SG)'),
#  ('BB Connect-IIG', 'Apple (SG)'),
#  ('BB Connect-IIG', 'BBIX (SG)'),
#  ('BB Connect-IIG', 'Beeline (LA)'),
#  ('BB Connect-IIG', 'CDNetworks (SG)'),
#  ('BB Connect-IIG', 'CloudFlare (SG)'),
#  ('BB Connect-IIG', 'Dailymotion (SG)'),
#  ('BB Connect-IIG', 'Digital Ocean (SG)'),
#  ('BB Connect-IIG', 'Dropbox (SG)'),
#  ('BB Connect-IIG', 'EdgeCast (SG)'),
#  ('BB Connect-IIG', 'Equinix (SG)'),
#  ('BB Connect-IIG', 'ETL (LA)'),
#  ('BB Connect-IIG', 'Facebook (SG)'),
#  ('BB Connect-IIG', 'Globe Telecom (SG)'),
#  ('BB Connect-IIG', 'Google (SG)'),
#  ('BB Connect-IIG', 'Hurricane (SG)'),
#  ('BB Connect-IIG', 'KDDI (SG)'),
#  ('BB Connect-IIG', 'LAO Telecom (LA)'),
#  ('BB Connect-IIG', 'LimeLight (SG)'),
#  ('BB Connect-IIG', 'Linkedin (SG)'),
#  ('BB Connect-IIG', 'Hurrican (SG)'),
#  ('BB Connect-IIG', 'Microsoft (SG)'),
#  ('BB Connect-IIG', 'Netflix (SG)'),
#  ('BB Connect-IIG', 'Netnod (SG)'),
#  ('BB Connect-IIG', 'NHN (SG)'),
#  ('BB Connect-IIG', 'NTT (SG)'),
#  ('BB Connect-IIG', 'OpenDNS (SG)'),
#  ('BB Connect-IIG', 'PCCW (HK)'),
#  ('BB Connect-IIG', 'PCCW (SG)'),
#  ('BB Connect-IIG', 'SG.GS (SG)'),
#  ('BB Connect-IIG', 'SGIX (SG)'),
#  ('BB Connect-IIG', 'SOFTBANK (SG)'),
#  ('BB Connect-IIG', 'SoftLayer (SG)'),
#  ('BB Connect-IIG', 'Swisscom (SG)'),
#  ('BB Connect-IIG', 'TM (MY)'),
#  ('BB Connect-IIG', 'Twitch (SG)'),
#  ('BB Connect-IIG', 'Twitter (SG)'),
#  ('BB Connect-IIG', 'UNITEL (LA)'),
#  ('BB Connect-IIG', 'VALVE (SG)'),
#  ('BB Connect-IIG', 'Viewqwest (SG)'),
#  ('BB Connect-IIG', 'Vocus (AU)'),
#  ('BB Connect-IIG', 'Yahoo (SG)'),
#  ('BB Connect-IIG', 'Zenlayer (SG)'),
#  ('AS45629', 'Ji-NET'),
#  ('AS45629', 'Triple T Internet'),
#  ('AS45629', 'Samart Infonet'),
#  ('AS45629', 'KSC'),
#  ('AS45629', 'INET'),
#  ('AS45629', '2S1N'),
#  ('AS45629', 'ISPIO (NIPA)'),
#  ('AS45629', 'PTT ICT'),
#  ('AS45629', 'Apple (SG)'),
#  ('AS45629', 'China Telecom (HK)'),
#  ('AS45629', 'COGENT (US)'),
#  ('AS45629', 'DTAG (FR)'),
#  ('AS45629', 'Equinix (FR)'),
#  ('AS45629', 'Equinix (SG)'),
#  ('AS45629', 'Facebook (MY)'),
#  ('AS45629', 'Facebook (SG)'),
#  ('AS45629', 'France IX (FR)'),
#  ('AS45629', 'Global Cloud Xchange(SG)'),
#  ('AS45629', 'Google (MY)'),
#  ('AS45629', 'GTC (MY)'),
#  ('AS45629', 'GTT (SG)\xa0'),
#  ('AS45629', 'HGC (HK)'),
#  ('AS45629', 'HKIX (HK)'),
#  ('AS45629', 'Level3 (US)'),
#  ('AS45629', 'Limelight (SG)'),
#  ('AS45629', 'Microsoft (SG)'),
#  ('AS45629', 'Netflix (SG)'),
#  ('AS45629', 'NHN (SG)\xa0'),
#  ('AS45629', 'NTT (SG)'),
#  ('AS45629', 'PCCW (SG)'),
#  ('AS45629', 'SingTel (SG)'),
#  ('AS45629', 'TATA (SG)'),
#  ('AS45629', 'Telstra (SG)'),
#  ('AS45629', 'TM (MY)\xa0'),
#  ('AS45629', 'Twitch (SG)'),
#  ('AS45629', 'Twitter (SG)'),
#  ('AS45629', 'Vodafone (SG)'),
#  ('AS45629', 'Yahoo (SG)'),
#  ('AS45629', 'AMS-IX (AN)'),
#  ('AS45629', 'Edgecast (SG)'),
#  ('AS45629', 'Amazon (SG)'),
#  ('AS45629', 'Hurricane (SG)'),
#  ('AS7568', 'CS Loxinfo'),
#  ('AS7568', 'AWN-IIG (SBN)'),
#  ('AS7568', 'Airtel (SG)'),
#  ('AS7568', 'Equinix (SG)'),
#  ('AS7568', 'Akamai (SG)'),
#  ('AS7568', 'Amazon.com (SG)'),
#  ('AS7568', 'Apple (SG)'),
#  ('AS7568', 'BIGLOBE (SG)'),
#  ('AS7568', 'Biznet Networks (SG)'),
#  ('AS7568', 'CBN Networks (SG)'),
#  ('AS7568', 'CDNetworks (SG)'),
#  ('AS7568', 'Cloudflare (SG)'),
#  ('AS7568', 'Core-Backbone (SG)'),
#  ('AS7568', 'Dropbox (SG)'),
#  ('AS7568', 'EdgeCast (SG)'),
#  ('AS7568', 'Etisalat (SG)'),
#  ('AS7568', 'Expereo (SG)'),
#  ('AS7568', 'Extreme Broadband (SG)'),
#  ('AS7568', 'EZIT (SG)'),
#  ('AS7568', 'EZNETSOLS (SG)'),
#  ('AS7568', 'Facebook (SG)'),
#  ('AS7568', 'Forcepoint (SG)'),
#  ('AS7568', 'GTC (SG)'),
#  ('AS7568', 'HitachiSunway (SG)'),
#  ('AS7568', 'Hurricane Electric (SG)'),
#  ('AS7568', 'iiNet (SG)'),
#  ('AS7568', 'Internet Harbor Global (SG)'),
#  ('AS7568', 'IP ServerOne (SG)'),
#  ('AS7568', 'LinkedIn (SG)'),
#  ('AS7568', 'Maxis (SG)'),
#  ('AS7568', 'Media Net (SG)'),
#  ('AS7568', 'Microsoft (SG)'),
#  ('AS7568', 'Moratelindo (SG'),
#  ('AS7568', 'MyRepublic (SG)'),
#  ('AS7568', 'NAP Info (SG)'),
#  ('AS7568', 'Netflix (SG)'),
#  ('AS7568', 'Netnod (SG)'),
#  ('AS7568', 'NewMedia Express(SG)'),
#  ('AS7568', 'NHN (SG)'),
#  ('AS7568', 'Pacific Internet (SG)'),
#  ('AS7568', 'PCH (SG)'),
#  ('AS7568', 'PCH (SG)'),
#  ('AS7568', 'Qatar Telecom (SG)'),
#  ('AS7568', 'ReadySpace Pte Ltd (SG)'),
#  ('AS7568', 'SecureAX (SG)'),
#  ('AS7568', 'SG.GS (SG)'),
#  ('AS7568', 'SINET (SG)'),
#  ('AS7568', 'SoftLayer (SG)'),
#  ('AS7568', 'SparkStation (SG)'),
#  ('AS7568', 'SuperInternet (SG)'),
#  ('AS7568', 'Swisscom (SG)'),
#  ('AS7568', 'Telecom Cambodia (SG)'),
#  ('AS7568', 'Telenor Global (SG)'),
#  ('AS7568', 'TELIN (SG)'),
#  ('AS7568', 'Trans Hybrid Communication (SG)'),
#  ('AS7568', 'Verizon (SG)'),
#  ('AS7568', 'ViewQwest (SG)'),
#  ('AS7568', 'Vocus (SG)'),
#  ('AS7568', 'Voxel (SG)'),
#  ('AS7568', 'XLNET (SG)'),
#  ('AS7568', 'Yahoo (SG)'),
#  ('AS7568', 'Zenlayer (SG)'),
#  ('AS7568', 'Facebook (MY)'),
#  ('AS7568', 'Global Cloud Xchange (SG)'),
#  ('AS7568', 'Google (MY)'),
#  ('AS7568', 'Google (SG)'),
#  ('AS7568', 'Microsoft (MY)'),
#  ('AS7568', 'NTT (SG)'),
#  ('AS7568', 'PCCW (SG)'),
#  ('AS7568', 'SingTel (SG)'),
#  ('AS7568', 'TATA (UK)'),
#  ('AS7568', 'Telecom Italia (SG)'),
#  ('AS7568', 'Telstra (SG)'),
#  ('AS7568', 'TeliaSonera (UK)'),
#  ('DTAC (IIG)', 'Dtac Trinet'),
#  ('DTAC (IIG)', 'BB Connect-IIG'),
#  ('DTAC (IIG)', 'INET'),
#  ('DTAC (IIG)', 'BBIX (SG)'),
#  ('DTAC (IIG)', 'Microsoft (SG)'),
#  ('DTAC (IIG)', 'Equinix (SG)'),
#  ('DTAC (IIG)', 'Akamai (SG)'),
#  ('DTAC (IIG)', 'Alibaba (SG)'),
#  ('DTAC (IIG)', 'Amazon (SG)'),
#  ('DTAC (IIG)', 'AOFEI (SG)'),
#  ('DTAC (IIG)', 'Apple (SG)'),
#  ('DTAC (IIG)', 'CloudFlare (SG)'),
#  ('DTAC (IIG)', 'EdgeCast (SG)'),
#  ('DTAC (IIG)', 'Expereo (SG)'),
#  ('DTAC (IIG)', 'EZIT (SG)'),
#  ('DTAC (IIG)', 'Hericane (SG)'),
#  ('DTAC (IIG)', 'IPServerOne (SG)'),
#  ('DTAC (IIG)', 'IPTransit (SG)'),
#  ('DTAC (IIG)', 'Leaseweb (SG)'),
#  ('DTAC (IIG)', 'Limelight (SG)'),
#  ('DTAC (IIG)', 'Netflix (SG)'),
#  ('DTAC (IIG)', 'NHN (SG)'),
#  ('DTAC (IIG)', 'OVH (SG)'),
#  ('DTAC (IIG)', 'PCH (SG)'),
#  ('DTAC (IIG)', 'SoftLayer (SG)'),
#  ('DTAC (IIG)', 'SparkStation (SG)'),
#  ('DTAC (IIG)', 'SuperInternet (SG)'),
#  ('DTAC (IIG)', 'Valvesoftware (SG)'),
#  ('DTAC (IIG)', 'Wikimedia (SG)'),
#  ('DTAC (IIG)', 'Yahoo (SG)'),
#  ('DTAC (IIG)', 'Facebook (MY)'),
#  ('DTAC (IIG)', 'Facebook (SG)'),
#  ('DTAC (IIG)', 'Google (MY)'),
#  ('DTAC (IIG)', 'Google (SG)'),
#  ('DTAC (IIG)', 'NHN (SG)'),
#  ('DTAC (IIG)', 'TATA (SG)'),
#  ('DTAC (IIG)', 'Telenor Global (MY)'),
#  ('DTAC (IIG)', 'Telenor Globa (MM)'),
#  ('DTAC (IIG)', 'Telenor Global (HK)'),
#  ('AS38082', 'A-Net'),
#  ('AS38082', 'INET'),
#  ('AS38082', 'ISSP'),
#  ('AS38082', 'KIRZ'),
#  ('AS38082', 'KSC'),
#  ('AS38082', 'NIPA.CLOUD'),
#  ('AS38082', 'NTT (TH)'),
#  ('AS38082', 'PROEN Internet'),
#  ('AS38082', 'SIAMDATA'),
#  ('AS38082', 'Smart Infonet'),
#  ('AS38082', 'True Internet Corporation'),
#  ('AS38082', 'Akamai (SG)'),
#  ('AS38082', 'AMS-IX (NL)'),
#  ('AS38082', 'BBIX (SG)'),
#  ('AS38082', 'Equinix (HK)'),
#  ('AS38082', 'Equinix (SG)'),
#  ('AS38082', 'Equinix (US)'),
#  ('AS38082', 'Facebook (MY)'),
#  ('AS38082', 'Facebook (SG)'),
#  ('AS38082', 'Google (MY)'),
#  ('AS38082', 'Google (SG)'),
#  ('AS38082', 'GTT (UK)'),
#  ('AS38082', 'HKIX (HK)'),
#  ('AS38082', 'Limelight (US)'),
#  ('AS38082', 'Limelight (SG)'),
#  ('AS38082', 'LINX (UK)'),
#  ('AS38082', 'Microsoft (SG)'),
#  ('AS38082', 'Microsoft (US)'),
#  ('AS38082', 'Netflix (SG)'),
#  ('AS38082', 'NTT (SG)'),
#  ('AS38082', 'NTT APAC (HK)'),
#  ('AS38082', 'Pacnet (SG)'),
#  ('AS38082', 'SingTel (SG)'),
#  ('AS38082', 'Sprint (US)'),
#  ('AS38082', 'StarHub (SG)'),
#  ('AS38082', 'TATA (SG)'),
#  ('AS38082', 'Telia Sonera (NL)'),
#  ('AS38082', 'Telstra (SG)'),
#  ('AS38082', 'Twitch (SG)'),
#  ('AS38082', 'Twitter (SG)'),
#  ('AS38082', 'Valve (SG)'),
#  ('AS38082', 'Amazon (SG)'),
#  ('AS38082', 'EdgeCast (SG)'),
#  ('AS132876', 'Symphony-ISP'),
#  ('AS132876', 'PROEN Internet'),
#  ('AS132876', 'Uninet'),
#  ('AS132876', 'A-Net'),
#  ('AS132876', '1-to-All'),
#  ('AS132876', 'Samart Infonet'),
#  ('AS132876', 'Loxley'),
#  ('AS132876', 'Milcom'),
#  ('AS132876', 'INET'),
#  ('AS132876', 'AMS-IX (NL)'),
#  ('AS132876', '1&1 Internet (NL)'),
#  ('AS132876', 'AT&T (NL)'),
#  ('AS132876', 'Bandwidth Technologies (NL)'),
#  ('AS132876', 'Blizzard (NL)'),
#  ('AS132876', 'Daliymotion (NL)'),
#  ('AS132876', 'Dropbox (NL)'),
#  ('AS132876', 'InterConnect (NL)'),
#  ('AS132876', 'Liquid Telecom (NL)'),
#  ('AS132876', 'Mainsoft (NL)'),
#  ('AS132876', 'MANDA (NL)'),
#  ('AS132876', 'Netrouting (NL)'),
#  ('AS132876', 'PLEX (NL)'),
#  ('AS132876', 'Sunrise (NL)'),
#  ('AS132876', 'Telenor (NL)'),
#  ('AS132876', 'Twicth (NL)'),
#  ('AS132876', 'Voxility (NL)'),
#  ('AS132876', 'Zayo (NL)'),
#  ('AS132876', 'ATOM86 (NL)'),
#  ('AS132876', 'CLARA (NL)'),
#  ('AS132876', 'FERAL (NL)'),
#  ('AS132876', 'OPENCARRIER (NL)'),
#  ('AS132876', 'SOCO (NL)'),
#  ('AS132876', 'WIOCC (NL)'),
#  ('AS132876', 'APPLE (SG)'),
#  ('AS132876', 'CHT (HK)'),
#  ('AS132876', 'Cogent (HK)'),
#  ('AS132876', 'DE-CIX (DE)'),
#  ('AS132876', '1&1 Internet (DE)'),
#  ('AS132876', 'AT&T (DE)'),
#  ('AS132876', 'Blizzard (DE)'),
#  ('AS132876', 'Comnet (DE)'),
#  ('AS132876', 'Daliymotion (DE)'),
#  ('AS132876', 'Dropbox (DE)'),
#  ('AS132876', 'HostEurope (DE)'),
#  ('AS132876', 'HostServer (DE)'),
#  ('AS132876', 'Liquid Telecom (DE)'),
#  ('AS132876', 'MANDA (DE)'),
#  ('AS132876', 'Netrouting (DE)'),
#  ('AS132876', 'NFOrce (DE)'),
#  ('AS132876', 'PCH (DE)'),
#  ('AS132876', 'SOCO (DE)'),
#  ('AS132876', 'Sunrise (DE)'),
#  ('AS132876', 'Telenor (DE)'),
#  ('AS132876', 'Twicth (DE)'),
#  ('AS132876', 'Voxility (DE)'),
#  ('AS132876', 'CITYNET (DE)'),
#  ('AS132876', 'CLARA (DE)'),
#  ('AS132876', 'GAMEFORGE (DE)'),
#  ('AS132876', 'GENIUSNETWORKS (DE)'),
#  ('AS132876', 'OPENCARRIER (DE)'),
#  ('AS132876', 'Telehouse (DE)'),
#  ('AS132876', 'WIOCC (DE)'),
#  ('AS132876', 'Equinix (SG)'),
#  ('AS132876', 'Akamai (SG)'),
#  ('AS132876', 'Amazon (SG)'),
#  ('AS132876', 'Areti Internet (SG)'),
#  ('AS132876', 'AT&T (SG)'),
#  ('AS132876', 'Biznet (SG)'),
#  ('AS132876', 'British Telecom (SG)'),
#  ('AS132876', 'CDNetworks (SG)'),
#  ('AS132876', 'CloudFlare (SG)'),
#  ('AS132876', 'Core-Backbone (SG)'),
#  ('AS132876', 'Dailymotion (SG)'),
#  ('AS132876', 'Dhiraagu (SG)'),
#  ('AS132876', 'Digital Ocean (SG)'),
#  ('AS132876', 'EdgeCast  (SG)'),
#  ('AS132876', 'Etisalat (SG)'),
#  ('AS132876', 'EZNETSOLS (SG)'),
#  ('AS132876', 'FASTLY (SG)'),
#  ('AS132876', 'GoDaddy (SG)'),
#  ('AS132876', 'GTC (SG)'),
#  ('AS132876', 'Hurricane (SG)'),
#  ('AS132876', 'IIJ (SG)'),
#  ('AS132876', 'INDOSAT (SG)'),
#  ('AS132876', 'IP ServerOne (SG)'),
#  ('AS132876', 'Kakao (SG)'),
#  ('AS132876', 'Level 3 (SG)'),
#  ('AS132876', 'Limelight (SG)'),
#  ('AS132876', 'LinkedIn (SG)'),
#  ('AS132876', 'Media Net (SG)'),
#  ('AS132876', 'Microsoft (SG)'),
#  ('AS132876', 'Moratelindo (SG)'),
#  ('AS132876', 'MyRepublic (SG)'),
#  ('AS132876', 'Netflix (SG)'),
#  ('AS132876', 'Netnod (SG)'),
#  ('AS132876', 'NHN (SG)'),
#  ('AS132876', 'OpenDNS (SG)'),
#  ('AS132876', 'PCH (SG)'),
#  ('AS132876', 'PCH (SG)'),
#  ('AS132876', 'Qatar Telecom (SG)'),
#  ('AS132876', 'SG.GS (SG)'),
#  ('AS132876', 'SoftLayer (SG)'),
#  ('AS132876', 'Sparkstation (SG)'),
#  ('AS132876', 'SuperInternet (SG)'),
#  ('AS132876', 'Swisscom (SG)'),
#  ('AS132876', 'Telin (SG)'),
#  ('AS132876', 'Trans Hybrid (SG)'),
#  ('AS132876', 'Twitter  (SG)'),
#  ('AS132876', 'VALVE (SG)'),
#  ('AS132876', 'Viewqwest (SG)'),
#  ('AS132876', 'Vocus (SG)'),
#  ('AS132876', 'Voxel (SG)'),
#  ('AS132876', 'Wargaming (SG)'),
#  ('AS132876', 'Wharf T&T (SG)'),
#  ('AS132876', 'Yahoo (SG)'),
#  ('AS132876', 'Zenlayer (SG)'),
#  ('AS132876', 'BhutanTelecom (SG)'),
#  ('AS132876', 'CLARA (SG)'),
#  ('AS132876', 'DOSARREST (SG)'),
#  ('AS132876', 'EXPEREO (SG)'),
#  ('AS132876', 'HERE Global BV (SG)'),
#  ('AS132876', 'Level3 GBLX (SG)'),
#  ('AS132876', 'OVH (SG)'),
#  ('AS132876', 'ZSCALER (SG)'),
#  ('AS132876', 'Ezecom (KH)'),
#  ('AS132876', 'Facebook (SG)'),
#  ('AS132876', 'FRANCE IX'),
#  ('AS132876', 'Akamai (FR)'),
#  ('AS132876', 'AT&T (FR)'),
#  ('AS132876', 'Blizzard (FR)'),
#  ('AS132876', 'Google (MY)'),
#  ('AS132876', 'Google (SG)'),
#  ('AS132876', 'GTT (SG)'),
#  ('AS132876', 'HGC (SG)'),
#  ('AS132876', 'HKIX (HK)'),
#  ('AS132876', 'ACME (HK)'),
#  ('AS132876', 'ANCHNET (HK)'),
#  ('AS132876', 'Anycast (HK)'),
#  ('AS132876', 'Asia Pacific Telecom (HK)'),
#  ('AS132876', 'AT&T (HK)'),
#  ('AS132876', 'Baidu (HK)'),
#  ('AS132876', 'CNS-KBT (HK)'),
#  ('AS132876', 'Etisalat (HK)'),
#  ('AS132876', 'FPT Telecom (HK)'),
#  ('AS132876', 'HKBN (HK)'),
#  ('AS132876', 'i4HK (HK)'),
#  ('AS132876', 'Rackspace (HK)'),
#  ('AS132876', 'VTC (HK)'),
#  ('AS132876', 'Zenlayer (HK)'),
#  ('AS132876', 'Dialpad (HK)'),
#  ('AS132876', 'NetActuate (HK)'),
#  ('AS132876', 'Leaseweb (HK)'),
#  ('AS132876', 'HE (HK)'),
#  ('AS132876', 'DROPBOX (HK)'),
#  ('AS132876', 'BIH (HK)'),
#  ('AS132876', 'Akamai (HK)'),
#  ('AS132876', 'Microsoft (HK)'),
#  ('AS132876', 'PCH (HK)'),
#  ('AS132876', 'Lao Gateway (LA)'),
#  ('AS132876', 'LINX (UK)'),
#  ('AS132876', '1&1 Internet (UK)'),
#  ('AS132876', 'AT&T (UK)'),
#  ('AS132876', 'Blizzard (UK)'),
#  ('AS132876', 'Catalyst2 (UK)'),
#  ('AS132876', 'ColocationIX (UK)'),
#  ('AS132876', 'Daliymotion (UK)'),
#  ('AS132876', 'Dropbox (UK)'),
#  ('AS132876', 'HostEurope (UK)'),
#  ('AS132876', 'Liquid Telecom (UK)'),
#  ('AS132876', 'MANDA (UK)'),
#  ('AS132876', 'Netrouting (UK)'),
#  ('AS132876', 'PCH (UK)'),
#  ('AS132876', 'Sunrise (UK)'),
#  ('AS132876', 'Telenor (UK)'),
#  ('AS132876', 'Twicth (UK)'),
#  ('AS132876', 'Voxility (UK)'),
#  ('AS132876', 'Zen Internet (UK)'),
#  ('AS132876', 'CLARA (UK)'),
#  ('AS132876', 'DOSARREST (UK)'),
#  ('AS132876', 'EXPEREO (UK)'),
#  ('AS132876', 'FERAL (UK)'),
#  ('AS132876', 'GENIUSNETWORKS (UK)'),
#  ('AS132876', 'SOCO (UK)'),
#  ('AS132876', 'WIOCC (UK)'),
#  ('AS132876', 'NYIIX (US)'),
#  ('AS132876', 'Atlantic Metro (US)'),
#  ('AS132876', 'NetActuate (US)'),
#  ('AS132876', 'Planetcom (LA)'),
#  ('AS132876', 'SingTel (SG)'),
#  ('AS132876', 'SKY Telecom (Lao)'),
#  ('AS132876', 'TATA (SG)'),
#  ('AS132876', 'Telia Sonera (SG)'),
#  ('AS132876', 'Twitch (SG)'),
#  ('AS132876', 'VALVE (SG)'),
#  ('CCT (SG)', 'TOT-IIG'),
#  ('CCT (SG)', 'TCCT-ISP'),
#  ('CCT (SG)', 'OTARO'),
#  ('CCT (SG)', 'Dots Solutions'),
#  ('CCT (SG)', 'CHT (HK)'),
#  ('CCT (SG)', 'NTC (KH)'),
#  ('CCT (SG)', 'Equinix (SG)'),
#  ('CCT (SG)', 'Akamai (SG)'),
#  ('CCT (SG)', 'Apple (SG)'),
#  ('CCT (SG)', 'Biznet (SG)'),
#  ('CCT (SG)', 'CDNetworks (SG)'),
#  ('CCT (SG)', 'CloudFlare (SG)'),
#  ('CCT (SG)', 'Digital Ocean (SG)'),
#  ('CCT (SG)', 'Dosarest (SG)'),
#  ('CCT (SG)', 'EdgeCast Networks (SG)'),
#  ('CCT (SG)', 'EZNETSOLS (SG)'),
#  ('CCT (SG)', 'FPT (VN)'),
#  ('CCT (SG)', 'Google (SG)'),
#  ('CCT (SG)', 'GTC (SG)'),
#  ('CCT (SG)', 'Hurricane (SG)'),
#  ('CCT (SG)', 'INDOSAT (SG)'),
#  ('CCT (SG)', 'Internet Harbor Global (SG)'),
#  ('CCT (SG)', 'Microsoft (SG)'),
#  ('CCT (SG)', 'Netflix (SG)'),
#  ('CCT (SG)', 'Netnod (SG)'),
#  ('CCT (SG)', 'PCH (SG)'),
#  ('CCT (SG)', 'PCH (SG)'),
#  ('CCT (SG)', 'SoftLayer (SG)'),
#  ('CCT (SG)', 'Spotify (SG)'),
#  ('CCT (SG)', 'Tencent (SG)'),
#  ('CCT (SG)', 'Twitter (SG)'),
#  ('CCT (SG)', 'VALVE (SG)'),
#  ('CCT (SG)', 'Yahoo (SG)'),
#  ('CCT (SG)', 'QUANTIL (HK)'),
#  ('CCT (SG)', 'CCT (SG)'),
#  ('CCT (SG)', 'VALVE (SG)'),
#  ('CCT (SG)', 'CloudFlare (SG)'),
#  ('CCT (SG)', 'Hurricane (SG)'),
#  ('CCT (SG)', 'Netnod (SG)'),
#  ('CCT (SG)', 'PCH (SG)'),
#  ('CCT (SG)', 'VALVE (SG)'),
#  ('TOT-IIG', 'GIN'),
#  ('TOT-IIG', 'INET'),
#  ('TOT-IIG', 'MOE'),
#  ('TOT-IIG', 'PROEN'),
#  ('TOT-IIG', 'TCCT-IIG'),
#  ('TOT-IIG', 'TCCT-ISP'),
#  ('TOT-IIG', 'TOT ISP'),
#  ('TOT-IIG', 'TOT LLI'),
#  ('TOT-IIG', 'TOT-IDC'),
#  ('TOT-IIG', 'Akamai (SG)'),
#  ('TOT-IIG', 'Amazon (SG)'),
#  ('TOT-IIG', 'AMS-IX (NL)'),
#  ('TOT-IIG', 'Any2Coresite (US)'),
#  ('TOT-IIG', 'Apple (SG)'),
#  ('TOT-IIG', 'China Telecom (HK)'),
#  ('TOT-IIG', 'Cloudflare (SG)'),
#  ('TOT-IIG', 'DE-CIX (DE)'),
#  ('TOT-IIG', 'Cogent (US)'),
#  ('TOT-IIG', 'Dailymotion (SG)'),
#  ('TOT-IIG', 'EdgeCast (SG)'),
#  ('TOT-IIG', 'Equinix (SG)'),
#  ('TOT-IIG', 'Equinix-SJC (US)'),
#  ('TOT-IIG', 'Facebook (MY)'),
#  ('TOT-IIG', 'Facebook (SG)'),
#  ('TOT-IIG', 'Google (MY)'),
#  ('TOT-IIG', 'Google (SG)'),
#  ('TOT-IIG', 'HKBN (HK)'),
#  ('TOT-IIG', 'HKIX (HK)'),
#  ('TOT-IIG', 'France IX (Fr)'),
#  ('TOT-IIG', 'Limelight (SG)'),
#  ('TOT-IIG', 'Microsoft (SG)'),
#  ('TOT-IIG', 'Netflix (SG)'),
#  ('TOT-IIG', 'NHN (SG)'),
#  ('TOT-IIG', 'NTT (SG)'),
#  ('TOT-IIG', 'Level3 (US)'),
#  ('TOT-IIG', 'SKB (KR)'),
#  ('TOT-IIG', 'StarHub (SG)'),
#  ('TOT-IIG', 'Telecom Italia (SG)'),
#  ('TOT-IIG', 'LINX (UK)'),
#  ('TOT-IIG', 'Teliasonera (SG)'),
#  ('TOT-IIG', 'Twitch (SG)'),
#  ('TOT-IIG', 'VALVE (SG)'),
#  ('TOT-IIG', 'Verizon (US)'),
#  ('1-to-All', 'GTC (MY)'),
#  ('AS45458', 'Telstra (SG)'),
#  ('AS45458', 'Telstra (HK)'),
#  ('AS45458', 'NTT (HK)'),
#  ('AS45458', 'PCCW (HK)'),
#  ('CAT-ISP', 'ETL (LA)'),
#  ('CAT-ISP', 'LAO Telecom (LA)'),
#  ('CAT-ISP', 'Equinix (SG)'),
#  ('CAT-ISP', 'CHT-I (TW)'),
#  ('CAT-ISP', 'UNITEL (LAOS)'),
#  ('KIRZ', 'CHT (SG)'),
#  ('KIRZ', 'NTT (SG)'),
#  ('KIRZ', 'GTC (MY)'),
#  ('Pacific Internet', 'Pacific Internet (SG)'),
#  ('Pacific Internet', 'HGC (HK)'),
#  ('SIAMDATA', 'HGC (HK)'),
#  ('PROEN Internet', 'NexusGuard (SG)'),
#  ('PROEN Internet', 'NexusGuard (HK)'),
#  ('AS24475', 'TEIN4 (HK)'),
#  ('AS24475', 'JGN-IX (SG)'),
#  ('Triple T Internet', 'Any2Coresite (US)'),
#  ('Triple T Internet', 'C&W (FR)'),
#  ('Triple T Internet', 'CHT (SG)'),
#  ('Triple T Internet', 'Cogent (FR)'),
#  ('Triple T Internet', 'Cogent (US)'),
#  ('Triple T Internet', 'DE-CIX (DE)'),
#  ('Triple T Internet', 'Equinix-SJC (US)'),
#  ('Triple T Internet', 'Global Cloud Xchang (SG)'),
#  ('Triple T Internet', 'L3 (US)'),
#  ('Triple T Internet', 'Microsoft (US)'),
#  ('Triple T Internet', 'nLayer (US)'),
#  ('Triple T Internet', 'NTT (SG)'),
#  ('Triple T Internet', 'PAIX (US)'),
#  ('Triple T Internet', 'PCCW (HK)'),
#  ('Triple T Internet', 'TATA (US)'),
#  ('Triple T Internet', 'Telecom Italia (FR)'),
#  ('Triple T Internet', 'Telesonera (FR)'),
#  ('Triple T Internet', 'Singtel (SG)'),
#  ('UIH (Beenet)', 'Microsoft (SG)'),
#  ('UIH (Beenet)', 'Amazon (SG)')]

# %%
def new_node(color, label, attributes, x, y, _id):
    node = {}
    node["color"] = color
    node["label"] = label
    node["attributes"] = attributes
    node["y"] = y
    node["x"] = x
    node["id"] = _id
    node["size"] = len([1 for pair in EDGES if label in pair]) * 5
    return node

# %%
def new_edge(sourceID, attributes, targetID, size):
    edge = {}
    edge["sourceID"] = sourceID
    edge["attributes"] = attributes
    edge["targetID"] = targetID
    edge["size"] = size
    return edge

# %%
colors = [
"#C91F37",
"#DC3023",
"#9D2933",
"#CF000F",
"#E68364",
"#F22613",
"#CF3A24",
"#C3272B",
"#8F1D21",
"#D24D57",
"#F08F907",
"#F47983",
"#DB5A6B",
"#C93756",
"#FCC9B9",
"#FFB3A7",
"#F62459",
"#F58F84",
"#875F9A",
"#5D3F6A",
"#89729E",
"#763568",
"#8D608C",
"#A87CA0",
"#5B3256",
"#BF55EC",
"#8E44AD",
"#9B59B6",
"#BE90D4",
"#4D8FAC",
"#5D8CAE",
"#22A7F0",
"#19B5FE",
"#59ABE3",
"#48929B",
"#317589",
"#89C4F4",
"#4B77BE",
"#1F4788",
"#003171",
"#044F67",
"#264348",
"#7A942E",
"#8DB255",
"#5B8930",
"#6B9362",
"#407A52",
"#006442",
"#87D37C",
"#26A65B",
"#26C281",
"#049372",
"#2ABB9B",
"#16A085",
"#36D7B7",
"#03A678",
"#4DAF7C",
"#D9B611",
"#F3C13A",
"#F7CA18",
"#E2B13C",
"#A17917",
"#F5D76E",
"#F4D03F",
"#FFA400",
"#E08A1E",
"#FFB61E",
"#FAA945",
"#FFA631",
"#FFB94E",
"#E29C45",
"#F9690E",
"#CA6924",
"#F5AB35",
"#BFBFBF",
"#F2F1EF",
"#BDC3C7",
"#ECF0F1",
"#D2D7D3",
"#757D75",
"#EEEEEE",
"#ABB7B7",
"#6C7A89",
"#95A5A6"]
colors_count = len(colors)

# %%
def gen_nodes(names):
    nodes = []
    for node in names:
        nodes.append(
            new_node(
                color=colors[randint(0, colors_count-1)], 
                label=node, 
                attributes={}, 
                x=randint(-5, 5), 
                y=randint(-5, 5), 
                _id=node
            )
        )
    return nodes
domestic_nodes = gen_nodes(domestic_names)
inter_nodes = gen_nodes(inter_names)
inter_nodes
# Out:
# [{'attributes': {},
#   'color': '#F4D03F',
#   'id': 'CS Loxinfo',
#   'label': 'CS Loxinfo',
#   'size': 5,
#   'x': 0,
#   'y': -3},
#  {'attributes': {},
#   'color': '#003171',
#   'id': 'MANDA (UK)',
#   'label': 'MANDA (UK)',
#   'size': 0,
#   'x': -2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#E2B13C',
#   'id': 'Beeline (LA)',
#   'label': 'Beeline (LA)',
#   'size': 0,
#   'x': 5,
#   'y': -2},
#  {'attributes': {},
#   'color': '#26A65B',
#   'id': 'AT&T (DE)',
#   'label': 'AT&T (DE)',
#   'size': 0,
#   'x': 4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'SOFTBANK (SG)',
#   'label': 'SOFTBANK (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#049372',
#   'id': 'Limelight (US)',
#   'label': 'Limelight (US)',
#   'size': 0,
#   'x': 5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'Triple T Internet',
#   'label': 'Triple T Internet',
#   'size': 25,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'Zayo (NL)',
#   'label': 'Zayo (NL)',
#   'size': 0,
#   'x': 0,
#   'y': 0},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'TATA (SG)',
#   'label': 'TATA (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'VALVE (SG)',
#   'label': 'VALVE (SG)',
#   'size': 0,
#   'x': -3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#6B9362',
#   'id': 'Vocus (SG)',
#   'label': 'Vocus (SG)',
#   'size': 0,
#   'x': 5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'CDNetworks (SG)',
#   'label': 'CDNetworks (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'Symphony-ISP',
#   'label': 'Symphony-ISP',
#   'size': 20,
#   'x': 3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#8D608C',
#   'id': 'Zenlayer (HK)',
#   'label': 'Zenlayer (HK)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F3C13A',
#   'id': 'PTT ICT',
#   'label': 'PTT ICT',
#   'size': 10,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'StarHub (SG)',
#   'label': 'StarHub (SG)',
#   'size': 0,
#   'x': -5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#F2F1EF',
#   'id': 'TEIN4 (HK)',
#   'label': 'TEIN4 (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'Hurricane Electric (SG)',
#   'label': 'Hurricane Electric (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'Twitch (SG)',
#   'label': 'Twitch (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'CAT ON Net',
#   'label': 'CAT ON Net',
#   'size': 5,
#   'x': -1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'Dropbox (NL)',
#   'label': 'Dropbox (NL)',
#   'size': 0,
#   'x': -2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'Trans Hybrid Communication (SG)',
#   'label': 'Trans Hybrid Communication (SG)',
#   'size': 0,
#   'x': 2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'BhutanTelecom (SG)',
#   'label': 'BhutanTelecom (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#407A52',
#   'id': 'Hericane (SG)',
#   'label': 'Hericane (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'Telecom Italia (FR)',
#   'label': 'Telecom Italia (FR)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#19B5FE',
#   'id': '1-Net (SG)',
#   'label': '1-Net (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#757D75',
#   'id': 'TATA (UK)',
#   'label': 'TATA (UK)',
#   'size': 0,
#   'x': -4,
#   'y': -3},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'Amazon (SG)',
#   'label': 'Amazon (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 3},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'Anycast (HK)',
#   'label': 'Anycast (HK)',
#   'size': 0,
#   'x': 0,
#   'y': 3},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'BBIX (HK)',
#   'label': 'BBIX (HK)',
#   'size': 0,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#4D8FAC',
#   'id': 'FPT Telecom (HK)',
#   'label': 'FPT Telecom (HK)',
#   'size': 0,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'DROPBOX (HK)',
#   'label': 'DROPBOX (HK)',
#   'size': 0,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#6B9362',
#   'id': 'AWN-IIG (SBN)',
#   'label': 'AWN-IIG (SBN)',
#   'size': 0,
#   'x': -3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'AT&T (FR)',
#   'label': 'AT&T (FR)',
#   'size': 0,
#   'x': 2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'France IX (FR)',
#   'label': 'France IX (FR)',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'Hurricane (US)',
#   'label': 'Hurricane (US)',
#   'size': 0,
#   'x': -3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#4D8FAC',
#   'id': 'CLARA (DE)',
#   'label': 'CLARA (DE)',
#   'size': 0,
#   'x': 4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#407A52',
#   'id': 'GTT (SG)',
#   'label': 'GTT (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'CHT (SG)',
#   'label': 'CHT (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#8F1D21',
#   'id': 'ICT MOF',
#   'label': 'ICT MOF',
#   'size': 5,
#   'x': 2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F3C13A',
#   'id': 'Maxis (SG)',
#   'label': 'Maxis (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'AMS-IX (NL)',
#   'label': 'AMS-IX (NL)',
#   'size': 0,
#   'x': 5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#BF55EC',
#   'id': 'Vodafone (FR)\xa0',
#   'label': 'Vodafone (FR)\xa0',
#   'size': 0,
#   'x': -5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'PROEN',
#   'label': 'PROEN',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'Equinix San Jose (US)',
#   'label': 'Equinix San Jose (US)',
#   'size': 0,
#   'x': 2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'CloudFlare (SG)',
#   'label': 'CloudFlare (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -3},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Media Net (SG)',
#   'label': 'Media Net (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'IP ServerOne (SG)',
#   'label': 'IP ServerOne (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#BE90D4',
#   'id': 'GAMEFORGE (DE)',
#   'label': 'GAMEFORGE (DE)',
#   'size': 0,
#   'x': -2,
#   'y': 5},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'C&W (FR)',
#   'label': 'C&W (FR)',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#E08A1E',
#   'id': 'Blizzard (DE)',
#   'label': 'Blizzard (DE)',
#   'size': 0,
#   'x': -2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'UNITEL (LA)',
#   'label': 'UNITEL (LA)',
#   'size': 0,
#   'x': 5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'HERE Global BV (SG)',
#   'label': 'HERE Global BV (SG)',
#   'size': 0,
#   'x': -5,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'JPNAP (JP)',
#   'label': 'JPNAP (JP)',
#   'size': 0,
#   'x': -5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#F4D03F',
#   'id': 'DE-CIX (DE)',
#   'label': 'DE-CIX (DE)',
#   'size': 0,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'GlobalNet (MM)',
#   'label': 'GlobalNet (MM)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'ANCHNET (HK)',
#   'label': 'ANCHNET (HK)',
#   'size': 0,
#   'x': -1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#E68364',
#   'id': 'LAO Telecom (LA)',
#   'label': 'LAO Telecom (LA)',
#   'size': 0,
#   'x': 4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'Sprint (US)',
#   'label': 'Sprint (US)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'LimeLight (SG)',
#   'label': 'LimeLight (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'PLEX (NL)',
#   'label': 'PLEX (NL)',
#   'size': 0,
#   'x': 4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': '1&1 Internet (DE)',
#   'label': '1&1 Internet (DE)',
#   'size': 0,
#   'x': -1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#FAA945',
#   'id': 'WIOCC (DE)',
#   'label': 'WIOCC (DE)',
#   'size': 0,
#   'x': 0,
#   'y': -3},
#  {'attributes': {},
#   'color': '#A17917',
#   'id': 'Sparkstation (SG)',
#   'label': 'Sparkstation (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#9B59B6',
#   'id': 'BIH (HK)',
#   'label': 'BIH (HK)',
#   'size': 0,
#   'x': 3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#26C281',
#   'id': 'Netflix (SG)',
#   'label': 'Netflix (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#8F1D21',
#   'id': 'FERAL (UK)',
#   'label': 'FERAL (UK)',
#   'size': 0,
#   'x': -4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#763568',
#   'id': 'INFONET',
#   'label': 'INFONET',
#   'size': 0,
#   'x': -1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'Telecom Italia (SG)',
#   'label': 'Telecom Italia (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -1},
#  {'attributes': {},
#   'color': '#264348',
#   'id': 'SoftLayer (SG)',
#   'label': 'SoftLayer (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#C3272B',
#   'id': 'Telstra (SG)',
#   'label': 'Telstra (SG)',
#   'size': 0,
#   'x': 5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'AT&T (UK)',
#   'label': 'AT&T (UK)',
#   'size': 0,
#   'x': 2,
#   'y': 5},
#  {'attributes': {},
#   'color': '#4B77BE',
#   'id': 'Zen Internet (UK)',
#   'label': 'Zen Internet (UK)',
#   'size': 0,
#   'x': -2,
#   'y': 5},
#  {'attributes': {},
#   'color': '#FFA400',
#   'id': 'Level3 (US)',
#   'label': 'Level3 (US)',
#   'size': 0,
#   'x': -1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'LG DACOM (KR)',
#   'label': 'LG DACOM (KR)',
#   'size': 0,
#   'x': -3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'NTT (TH)',
#   'label': 'NTT (TH)',
#   'size': 20,
#   'x': -4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#003171',
#   'id': 'Pacific Internet',
#   'label': 'Pacific Internet',
#   'size': 5,
#   'x': 3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'CLARA (SG)',
#   'label': 'CLARA (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -5},
#  {'attributes': {},
#   'color': '#D2D7D3',
#   'id': 'Atlantic Metro (US)',
#   'label': 'Atlantic Metro (US)',
#   'size': 0,
#   'x': -3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'Netrouting (NL)',
#   'label': 'Netrouting (NL)',
#   'size': 0,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#DB5A6B',
#   'id': 'B Network Solution (BNS)',
#   'label': 'B Network Solution (BNS)',
#   'size': 0,
#   'x': -3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'ReadySpace Pte Ltd (SG)',
#   'label': 'ReadySpace Pte Ltd (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 0},
#  {'attributes': {},
#   'color': '#FCC9B9',
#   'id': 'GTT (SG)\xa0',
#   'label': 'GTT (SG)\xa0',
#   'size': 0,
#   'x': -5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Vodafone (SG)',
#   'label': 'Vodafone (SG)',
#   'size': 0,
#   'x': 5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'Airtel (SG)',
#   'label': 'Airtel (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'VNPT Corp (VN)',
#   'label': 'VNPT Corp (VN)',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#03A678',
#   'id': 'Microsoft (HK)',
#   'label': 'Microsoft (HK)',
#   'size': 0,
#   'x': 0,
#   'y': 1},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'BIGLOBE (SG)',
#   'label': 'BIGLOBE (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'TOT LLI',
#   'label': 'TOT LLI',
#   'size': 10,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'Level3 GBLX (SG)',
#   'label': 'Level3 GBLX (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#757D75',
#   'id': 'NLIX (NL)',
#   'label': 'NLIX (NL)',
#   'size': 0,
#   'x': -1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'Samart Infonet',
#   'label': 'Samart Infonet',
#   'size': 0,
#   'x': 2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'Telenor Global (HK)',
#   'label': 'Telenor Global (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'Catalyst2 (UK)',
#   'label': 'Catalyst2 (UK)',
#   'size': 0,
#   'x': -1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'Valvesoftware (SG)',
#   'label': 'Valvesoftware (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -3},
#  {'attributes': {},
#   'color': '#4D8FAC',
#   'id': 'Sunrise (DE)',
#   'label': 'Sunrise (DE)',
#   'size': 0,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'NIPA.CLOUD',
#   'label': 'NIPA.CLOUD',
#   'size': 25,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'KDDI (HK)',
#   'label': 'KDDI (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'NexusGuard (HK)',
#   'label': 'NexusGuard (HK)',
#   'size': 0,
#   'x': -2,
#   'y': -5},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Microsoft (US)',
#   'label': 'Microsoft (US)',
#   'size': 0,
#   'x': 3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#A17917',
#   'id': 'Zenlayer (SG)',
#   'label': 'Zenlayer (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'GTC (SG)',
#   'label': 'GTC (SG)',
#   'size': 0,
#   'x': 2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#763568',
#   'id': '1-to-All',
#   'label': '1-to-All',
#   'size': 0,
#   'x': -1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'DTAG (FR)',
#   'label': 'DTAG (FR)',
#   'size': 0,
#   'x': -4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#E68364',
#   'id': 'PCH (SG)',
#   'label': 'PCH (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#FFB61E',
#   'id': 'Asia Pacific Telecom (HK)',
#   'label': 'Asia Pacific Telecom (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#757D75',
#   'id': 'Twicth (NL)',
#   'label': 'Twicth (NL)',
#   'size': 0,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'GENIUSNETWORKS (UK)',
#   'label': 'GENIUSNETWORKS (UK)',
#   'size': 0,
#   'x': 3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'KIRZ',
#   'label': 'KIRZ',
#   'size': 20,
#   'x': 3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'BBIX (SG)',
#   'label': 'BBIX (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#E2B13C',
#   'id': 'OPENCARRIER (DE)',
#   'label': 'OPENCARRIER (DE)',
#   'size': 0,
#   'x': 0,
#   'y': 1},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'Baidu (HK)',
#   'label': 'Baidu (HK)',
#   'size': 0,
#   'x': 5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Cogent (SG)',
#   'label': 'Cogent (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'Voxel (SG)',
#   'label': 'Voxel (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -5},
#  {'attributes': {},
#   'color': '#264348',
#   'id': 'Kakao (SG)',
#   'label': 'Kakao (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'Cogent (HK)',
#   'label': 'Cogent (HK)',
#   'size': 0,
#   'x': 0,
#   'y': 0},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'OPENCARRIER (NL)',
#   'label': 'OPENCARRIER (NL)',
#   'size': 0,
#   'x': -5,
#   'y': -2},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'Twitter  (SG)',
#   'label': 'Twitter  (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'Uninet',
#   'label': 'Uninet',
#   'size': 0,
#   'x': 4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#4DAF7C',
#   'id': 'GIN',
#   'label': 'GIN',
#   'size': 5,
#   'x': -2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'Lao Gateway (LA)',
#   'label': 'Lao Gateway (LA)',
#   'size': 0,
#   'x': 0,
#   'y': 2},
#  {'attributes': {},
#   'color': '#044F67',
#   'id': 'HostServer (DE)',
#   'label': 'HostServer (DE)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Ezecom (KH)',
#   'label': 'Ezecom (KH)',
#   'size': 0,
#   'x': 1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'TM (MY)\xa0',
#   'label': 'TM (MY)\xa0',
#   'size': 0,
#   'x': 2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#C93756',
#   'id': 'TELIN (SG)',
#   'label': 'TELIN (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 3},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'NTT (SG)',
#   'label': 'NTT (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'ISSP',
#   'label': 'ISSP',
#   'size': 15,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'InterConnect (NL)',
#   'label': 'InterConnect (NL)',
#   'size': 0,
#   'x': -1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#407A52',
#   'id': 'NTC (KH)',
#   'label': 'NTC (KH)',
#   'size': 0,
#   'x': -2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#9B59B6',
#   'id': 'Telstra (HK)',
#   'label': 'Telstra (HK)',
#   'size': 0,
#   'x': 5,
#   'y': -1},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'Wargaming (SG)',
#   'label': 'Wargaming (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 2},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Hurricane (SG)',
#   'label': 'Hurricane (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 3},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'Forcepoint (SG)',
#   'label': 'Forcepoint (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'L3 (US)',
#   'label': 'L3 (US)',
#   'size': 0,
#   'x': -2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#763568',
#   'id': 'HE (HK)',
#   'label': 'HE (HK)',
#   'size': 0,
#   'x': 5,
#   'y': -2},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'Equinix (US)',
#   'label': 'Equinix (US)',
#   'size': 0,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#59ABE3',
#   'id': 'GTT (UK)',
#   'label': 'GTT (UK)',
#   'size': 0,
#   'x': 5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'XLNET (SG)',
#   'label': 'XLNET (SG)',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Digital Ocean (SG)',
#   'label': 'Digital Ocean (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#8E44AD',
#   'id': 'SKB (KR)',
#   'label': 'SKB (KR)',
#   'size': 0,
#   'x': -2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'SOCO (UK)',
#   'label': 'SOCO (UK)',
#   'size': 0,
#   'x': 4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'SparkStation (SG)',
#   'label': 'SparkStation (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'Hurricane (HK)',
#   'label': 'Hurricane (HK)',
#   'size': 0,
#   'x': 2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#BE90D4',
#   'id': 'Twicth (DE)',
#   'label': 'Twicth (DE)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F9690E',
#   'id': 'NYIIX (US)',
#   'label': 'NYIIX (US)',
#   'size': 0,
#   'x': 2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'Verizon (US)',
#   'label': 'Verizon (US)',
#   'size': 0,
#   'x': -5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#8DB255',
#   'id': 'EdgeCast  (SG)',
#   'label': 'EdgeCast  (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#FFA400',
#   'id': '1&1 Internet (NL)',
#   'label': '1&1 Internet (NL)',
#   'size': 0,
#   'x': -2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Dialpad (HK)',
#   'label': 'Dialpad (HK)',
#   'size': 0,
#   'x': 1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'Dtac Trinet',
#   'label': 'Dtac Trinet',
#   'size': 5,
#   'x': -2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'VTC (HK)',
#   'label': 'VTC (HK)',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'Telenor (UK)',
#   'label': 'Telenor (UK)',
#   'size': 0,
#   'x': 2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#8F1D21',
#   'id': 'INET',
#   'label': 'INET',
#   'size': 40,
#   'x': -1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'Global Cloud Xchang (SG)',
#   'label': 'Global Cloud Xchang (SG)',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#4DAF7C',
#   'id': 'ZSCALER (SG)',
#   'label': 'ZSCALER (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'Akamai (FR)',
#   'label': 'Akamai (FR)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'SGIX (SG)',
#   'label': 'SGIX (SG)',
#   'size': 0,
#   'x': 3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#BF55EC',
#   'id': 'CITYNET (DE)',
#   'label': 'CITYNET (DE)',
#   'size': 0,
#   'x': 0,
#   'y': -1},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Equinix (SG)',
#   'label': 'Equinix (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'Etisalat (HK)',
#   'label': 'Etisalat (HK)',
#   'size': 0,
#   'x': -1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#03A678',
#   'id': 'Limelight (SG)',
#   'label': 'Limelight (SG)',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#264348',
#   'id': 'Areti Internet (SG)',
#   'label': 'Areti Internet (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#48929B',
#   'id': 'Twicth (UK)',
#   'label': 'Twicth (UK)',
#   'size': 0,
#   'x': -3,
#   'y': -3},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'Dots Solutions',
#   'label': 'Dots Solutions',
#   'size': 5,
#   'x': -4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'ATOM86 (NL)',
#   'label': 'ATOM86 (NL)',
#   'size': 0,
#   'x': 2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#4DAF7C',
#   'id': 'nLayer (US)',
#   'label': 'nLayer (US)',
#   'size': 0,
#   'x': -5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'Etisalat (UAE)',
#   'label': 'Etisalat (UAE)',
#   'size': 0,
#   'x': 0,
#   'y': -5},
#  {'attributes': {},
#   'color': '#C3272B',
#   'id': 'Amazon.com (SG)',
#   'label': 'Amazon.com (SG)',
#   'size': 0,
#   'x': 0,
#   'y': 3},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'SuperInternet (SG)',
#   'label': 'SuperInternet (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'Vocus (AU)',
#   'label': 'Vocus (AU)',
#   'size': 0,
#   'x': -5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'Internet Harbor Global (SG)',
#   'label': 'Internet Harbor Global (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#8E44AD',
#   'id': 'Facebook (MY)',
#   'label': 'Facebook (MY)',
#   'size': 0,
#   'x': 4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'British Telecom (SG)',
#   'label': 'British Telecom (SG)',
#   'size': 0,
#   'x': -5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'PCH (HK)',
#   'label': 'PCH (HK)',
#   'size': 0,
#   'x': 2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#8DB255',
#   'id': 'SOCO (NL)',
#   'label': 'SOCO (NL)',
#   'size': 0,
#   'x': 2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#D24D57',
#   'id': 'Global Cloud Xchange(SG)',
#   'label': 'Global Cloud Xchange(SG)',
#   'size': 0,
#   'x': -5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#26C281',
#   'id': 'AMS-IX (AN)',
#   'label': 'AMS-IX (AN)',
#   'size': 0,
#   'x': -1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'NTT (HK)',
#   'label': 'NTT (HK)',
#   'size': 0,
#   'x': 2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#D24D57',
#   'id': 'TATA (US)',
#   'label': 'TATA (US)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'Telin (SG)',
#   'label': 'Telin (SG)',
#   'size': 0,
#   'x': -3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'IPTransit (SG)',
#   'label': 'IPTransit (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#03A678',
#   'id': 'EdgeCast Networks (SG)',
#   'label': 'EdgeCast Networks (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'Voxility (DE)',
#   'label': 'Voxility (DE)',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'UNITEL (LAOS)',
#   'label': 'UNITEL (LAOS)',
#   'size': 0,
#   'x': 5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Sky Telecom (LA)',
#   'label': 'Sky Telecom (LA)',
#   'size': 0,
#   'x': -4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#5D8CAE',
#   'id': 'Biznet (SG)',
#   'label': 'Biznet (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'Dailymotion (SG)',
#   'label': 'Dailymotion (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#8E44AD',
#   'id': 'Liquid Telecom (NL)',
#   'label': 'Liquid Telecom (NL)',
#   'size': 0,
#   'x': 5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'HostEurope (UK)',
#   'label': 'HostEurope (UK)',
#   'size': 0,
#   'x': 5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F2F1EF',
#   'id': 'Telenor (DE)',
#   'label': 'Telenor (DE)',
#   'size': 0,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#87D37C',
#   'id': 'CHT-I (TW)',
#   'label': 'CHT-I (TW)',
#   'size': 0,
#   'x': 0,
#   'y': 4},
#  {'attributes': {},
#   'color': '#19B5FE',
#   'id': 'CHT-I HiNet (TW)',
#   'label': 'CHT-I HiNet (TW)',
#   'size': 0,
#   'x': -3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Triple T Internet/ Triple T Broadband',
#   'label': 'Triple T Internet/ Triple T Broadband',
#   'size': 0,
#   'x': -5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'Extreme Broadband (SG)',
#   'label': 'Extreme Broadband (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'FRANCE IX',
#   'label': 'FRANCE IX',
#   'size': 0,
#   'x': -5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#D24D57',
#   'id': 'COGENT (US)',
#   'label': 'COGENT (US)',
#   'size': 0,
#   'x': 0,
#   'y': 4},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'OTARO',
#   'label': 'OTARO',
#   'size': 20,
#   'x': -1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'CLARA (NL)',
#   'label': 'CLARA (NL)',
#   'size': 0,
#   'x': -5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Any2Coresite (US)',
#   'label': 'Any2Coresite (US)',
#   'size': 0,
#   'x': 0,
#   'y': -3},
#  {'attributes': {},
#   'color': '#48929B',
#   'id': 'Twitter (SG)',
#   'label': 'Twitter (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 3},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'NewMedia Express(SG)',
#   'label': 'NewMedia Express(SG)',
#   'size': 0,
#   'x': 3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#044F67',
#   'id': 'iiNet (SG)',
#   'label': 'iiNet (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'OpenDNS (SG)',
#   'label': 'OpenDNS (SG)',
#   'size': 0,
#   'x': 2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Leaseweb (HK)',
#   'label': 'Leaseweb (HK)',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'SOCO (DE)',
#   'label': 'SOCO (DE)',
#   'size': 0,
#   'x': -4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'HitachiSunway (SG)',
#   'label': 'HitachiSunway (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#5D8CAE',
#   'id': 'CHT (HK)',
#   'label': 'CHT (HK)',
#   'size': 0,
#   'x': 3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#26A65B',
#   'id': 'UIH/ BEENET',
#   'label': 'UIH/ BEENET',
#   'size': 0,
#   'x': -3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Voxility (UK)',
#   'label': 'Voxility (UK)',
#   'size': 0,
#   'x': 4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Leaseweb (SG)',
#   'label': 'Leaseweb (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'UIH (Beenet)',
#   'label': 'UIH (Beenet)',
#   'size': 20,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#89C4F4',
#   'id': 'EZNETSOLS (SG)',
#   'label': 'EZNETSOLS (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#264348',
#   'id': 'Wharf T&T (SG)',
#   'label': 'Wharf T&T (SG)',
#   'size': 0,
#   'x': 3,
#   'y': 4},
#  {'attributes': {},
#   'color': '#FFA400',
#   'id': 'DOSARREST (SG)',
#   'label': 'DOSARREST (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'TOT ISP',
#   'label': 'TOT ISP',
#   'size': 30,
#   'x': 1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Moratelindo (SG',
#   'label': 'Moratelindo (SG',
#   'size': 0,
#   'x': 2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Telia Sonera (NL)',
#   'label': 'Telia Sonera (NL)',
#   'size': 0,
#   'x': 2,
#   'y': 1},
#  {'attributes': {},
#   'color': '#87D37C',
#   'id': 'Verizon (SG)',
#   'label': 'Verizon (SG)',
#   'size': 0,
#   'x': 5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#F5AB35',
#   'id': 'HGC (SG)',
#   'label': 'HGC (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'Moratelindo (SG)',
#   'label': 'Moratelindo (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'Microsoft (SG)',
#   'label': 'Microsoft (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'Cloudflare (SG)',
#   'label': 'Cloudflare (SG)',
#   'size': 0,
#   'x': 0,
#   'y': 2},
#  {'attributes': {},
#   'color': '#264348',
#   'id': 'MILCOM',
#   'label': 'MILCOM',
#   'size': 5,
#   'x': 4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'SKY Telecom (Lao)',
#   'label': 'SKY Telecom (Lao)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#BE90D4',
#   'id': 'HostEurope (DE)',
#   'label': 'HostEurope (DE)',
#   'size': 0,
#   'x': -2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#A17917',
#   'id': 'Blizzard (NL)',
#   'label': 'Blizzard (NL)',
#   'size': 0,
#   'x': 1,
#   'y': 2},
#  {'attributes': {},
#   'color': '#8E44AD',
#   'id': 'Level 3 (SG)',
#   'label': 'Level 3 (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#C3272B',
#   'id': 'SG.GS (SG)',
#   'label': 'SG.GS (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#19B5FE',
#   'id': 'TM (MY)',
#   'label': 'TM (MY)',
#   'size': 0,
#   'x': 3,
#   'y': 0},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'Akamai (SG)',
#   'label': 'Akamai (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -3},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'Telenor Global (SG)',
#   'label': 'Telenor Global (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#D2D7D3',
#   'id': 'Tencent (SG)',
#   'label': 'Tencent (SG)',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'True Internet Corporation',
#   'label': 'True Internet Corporation',
#   'size': 15,
#   'x': -3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#FAA945',
#   'id': 'SINET (SG)',
#   'label': 'SINET (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'ServeNET',
#   'label': 'ServeNET',
#   'size': 5,
#   'x': 4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'NetActuate (HK)',
#   'label': 'NetActuate (HK)',
#   'size': 0,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'WIOCC (NL)',
#   'label': 'WIOCC (NL)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'Alibaba (SG)',
#   'label': 'Alibaba (SG)',
#   'size': 0,
#   'x': -3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#19B5FE',
#   'id': 'Pacific Internet (SG)',
#   'label': 'Pacific Internet (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'INDOSAT (SG)',
#   'label': 'INDOSAT (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#8D608C',
#   'id': 'Telesonera (FR)',
#   'label': 'Telesonera (FR)',
#   'size': 0,
#   'x': -2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#D24D57',
#   'id': 'HGC (HK)',
#   'label': 'HGC (HK)',
#   'size': 0,
#   'x': -1,
#   'y': 2},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'CBN Networks (SG)',
#   'label': 'CBN Networks (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'PCH (DE)',
#   'label': 'PCH (DE)',
#   'size': 0,
#   'x': 0,
#   'y': 3},
#  {'attributes': {},
#   'color': '#26A65B',
#   'id': 'Google (SG)',
#   'label': 'Google (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'FERAL (NL)',
#   'label': 'FERAL (NL)',
#   'size': 0,
#   'x': -1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'PAIX (US)',
#   'label': 'PAIX (US)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'Google (MY)',
#   'label': 'Google (MY)',
#   'size': 0,
#   'x': -4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#407A52',
#   'id': 'Dropbox (SG)',
#   'label': 'Dropbox (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#E68364',
#   'id': 'NexusGuard (SG)',
#   'label': 'NexusGuard (SG)',
#   'size': 0,
#   'x': 2,
#   'y': -5},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'Milcom',
#   'label': 'Milcom',
#   'size': 0,
#   'x': -3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'Telecom Cambodia (SG)',
#   'label': 'Telecom Cambodia (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#8E44AD',
#   'id': 'NAP Info (SG)',
#   'label': 'NAP Info (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 4},
#  {'attributes': {},
#   'color': '#59ABE3',
#   'id': 'TeliaSonera (UK)',
#   'label': 'TeliaSonera (UK)',
#   'size': 0,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#89C4F4',
#   'id': 'Netrouting (UK)',
#   'label': 'Netrouting (UK)',
#   'size': 0,
#   'x': -1,
#   'y': 3},
#  {'attributes': {},
#   'color': '#FFA400',
#   'id': 'ISPIO (NIPA)',
#   'label': 'ISPIO (NIPA)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'Comnet (DE)',
#   'label': 'Comnet (DE)',
#   'size': 0,
#   'x': -1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'GENIUSNETWORKS (DE)',
#   'label': 'GENIUSNETWORKS (DE)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'AT&T (SG)',
#   'label': 'AT&T (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -2},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'Equinix (HK)',
#   'label': 'Equinix (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#95A5A6',
#   'id': 'Loxley',
#   'label': 'Loxley',
#   'size': 10,
#   'x': -5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#4DAF7C',
#   'id': 'UniNet',
#   'label': 'UniNet',
#   'size': 15,
#   'x': 3,
#   'y': -3},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'i4HK (HK)',
#   'label': 'i4HK (HK)',
#   'size': 0,
#   'x': -5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#FFB61E',
#   'id': 'Daliymotion (UK)',
#   'label': 'Daliymotion (UK)',
#   'size': 0,
#   'x': -5,
#   'y': -1},
#  {'attributes': {},
#   'color': '#48929B',
#   'id': '2S1N',
#   'label': '2S1N',
#   'size': 5,
#   'x': -3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F5D76E',
#   'id': 'Netrouting (DE)',
#   'label': 'Netrouting (DE)',
#   'size': 0,
#   'x': 5,
#   'y': -2},
#  {'attributes': {},
#   'color': '#87D37C',
#   'id': 'Qatar Telecom (SG)',
#   'label': 'Qatar Telecom (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'TCCT-ISP',
#   'label': 'TCCT-ISP',
#   'size': 10,
#   'x': -5,
#   'y': -1},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'Singtel (SG)',
#   'label': 'Singtel (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F2F1EF',
#   'id': 'Daliymotion (DE)',
#   'label': 'Daliymotion (DE)',
#   'size': 0,
#   'x': 4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#D2D7D3',
#   'id': 'Facebook (SG)',
#   'label': 'Facebook (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'Equinix-SJC (US)',
#   'label': 'Equinix-SJC (US)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#4D8FAC',
#   'id': 'EXPEREO (UK)',
#   'label': 'EXPEREO (UK)',
#   'size': 0,
#   'x': 4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'JGN-IX (SG)',
#   'label': 'JGN-IX (SG)',
#   'size': 0,
#   'x': 5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#FFA400',
#   'id': 'MANDA (DE)',
#   'label': 'MANDA (DE)',
#   'size': 0,
#   'x': -3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'HKBN (HK)',
#   'label': 'HKBN (HK)',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F5AB35',
#   'id': 'BB Connect-IIG',
#   'label': 'BB Connect-IIG',
#   'size': 0,
#   'x': -5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#DB5A6B',
#   'id': 'Bandwidth Technologies (NL)',
#   'label': 'Bandwidth Technologies (NL)',
#   'size': 0,
#   'x': 1,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F5D76E',
#   'id': 'Globe Telecom (SG)',
#   'label': 'Globe Telecom (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'MyRepublic (SG)',
#   'label': 'MyRepublic (SG)',
#   'size': 0,
#   'x': -3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#049372',
#   'id': 'HKIX (HK)',
#   'label': 'HKIX (HK)',
#   'size': 0,
#   'x': -5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'Voxility (NL)',
#   'label': 'Voxility (NL)',
#   'size': 0,
#   'x': -3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'Expereo (SG)',
#   'label': 'Expereo (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'ACME (HK)',
#   'label': 'ACME (HK)',
#   'size': 0,
#   'x': -1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#8DB255',
#   'id': 'MANDA (NL)',
#   'label': 'MANDA (NL)',
#   'size': 0,
#   'x': -3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Ji-NET',
#   'label': 'Ji-NET',
#   'size': 10,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'FPT (VN)',
#   'label': 'FPT (VN)',
#   'size': 0,
#   'x': 4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'Linkedin (SG)',
#   'label': 'Linkedin (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#FAA945',
#   'id': 'KSC',
#   'label': 'KSC',
#   'size': 15,
#   'x': 5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#95A5A6',
#   'id': 'Telenor Global (MY)',
#   'label': 'Telenor Global (MY)',
#   'size': 0,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'TeliaSonera (SG)',
#   'label': 'TeliaSonera (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Telstra (HK)\xa0',
#   'label': 'Telstra (HK)\xa0',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F5AB35',
#   'id': 'DTAC (IIG)',
#   'label': 'DTAC (IIG)',
#   'size': 0,
#   'x': 3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#763568',
#   'id': 'Etisalat (SG)',
#   'label': 'Etisalat (SG)',
#   'size': 0,
#   'x': 0,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'QUANTIL (HK)',
#   'label': 'QUANTIL (HK)',
#   'size': 0,
#   'x': 3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#DC3023',
#   'id': 'Biznet Networks (SG)',
#   'label': 'Biznet Networks (SG)',
#   'size': 0,
#   'x': 3,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F3C13A',
#   'id': 'TCCT-IIG',
#   'label': 'TCCT-IIG',
#   'size': 0,
#   'x': 3,
#   'y': 0},
#  {'attributes': {},
#   'color': '#8DB255',
#   'id': 'Pacnet (SG)',
#   'label': 'Pacnet (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'CCT (SG)',
#   'label': 'CCT (SG)',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#FAA945',
#   'id': 'Liquid Telecom (DE)',
#   'label': 'Liquid Telecom (DE)',
#   'size': 0,
#   'x': -3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#FFA631',
#   'id': 'TATA\xa0\xa0(IN)',
#   'label': 'TATA\xa0\xa0(IN)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#049372',
#   'id': 'MOE',
#   'label': 'MOE',
#   'size': 5,
#   'x': 4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#4D8FAC',
#   'id': 'Dhiraagu (SG)',
#   'label': 'Dhiraagu (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#C93756',
#   'id': 'Rackspace (HK)',
#   'label': 'Rackspace (HK)',
#   'size': 0,
#   'x': -3,
#   'y': 4},
#  {'attributes': {},
#   'color': '#8F1D21',
#   'id': 'Blizzard (FR)',
#   'label': 'Blizzard (FR)',
#   'size': 0,
#   'x': 0,
#   'y': -2},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'Google (HK)',
#   'label': 'Google (HK)',
#   'size': 0,
#   'x': -5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#A17917',
#   'id': 'IPServerOne (SG)',
#   'label': 'IPServerOne (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'Blizzard (UK)',
#   'label': 'Blizzard (UK)',
#   'size': 0,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'StarHub (SG)\xa0',
#   'label': 'StarHub (SG)\xa0',
#   'size': 0,
#   'x': 4,
#   'y': -3},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Dosarest (SG)',
#   'label': 'Dosarest (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'CNS-KBT (HK)',
#   'label': 'CNS-KBT (HK)',
#   'size': 0,
#   'x': -2,
#   'y': 1},
#  {'attributes': {},
#   'color': '#044F67',
#   'id': 'Wikimedia (SG)',
#   'label': 'Wikimedia (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#BF55EC',
#   'id': 'Trans Hybrid (SG)',
#   'label': 'Trans Hybrid (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -5},
#  {'attributes': {},
#   'color': '#5B3256',
#   'id': 'Microsoft (MY)',
#   'label': 'Microsoft (MY)',
#   'size': 0,
#   'x': 4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#BE90D4',
#   'id': 'A-Net',
#   'label': 'A-Net',
#   'size': 10,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'EXPEREO (SG)',
#   'label': 'EXPEREO (SG)',
#   'size': 0,
#   'x': -2,
#   'y': 2},
#  {'attributes': {},
#   'color': '#87D37C',
#   'id': 'TOT-IDC',
#   'label': 'TOT-IDC',
#   'size': 5,
#   'x': -3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#BFBFBF',
#   'id': 'NHN (SG)\xa0',
#   'label': 'NHN (SG)\xa0',
#   'size': 0,
#   'x': 5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'AT&T (HK)',
#   'label': 'AT&T (HK)',
#   'size': 0,
#   'x': 4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Dropbox (DE)',
#   'label': 'Dropbox (DE)',
#   'size': 0,
#   'x': -5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#8F1D21',
#   'id': 'Metrabyte',
#   'label': 'Metrabyte',
#   'size': 5,
#   'x': 2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'Viewqwest (SG)',
#   'label': 'Viewqwest (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#5B8930',
#   'id': 'KDDI (SG)',
#   'label': 'KDDI (SG)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#BDC3C7',
#   'id': 'Edgecast (SG)',
#   'label': 'Edgecast (SG)',
#   'size': 0,
#   'x': 3,
#   'y': 3},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'LINX (UK)',
#   'label': 'LINX (UK)',
#   'size': 0,
#   'x': 3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'NFOrce (DE)',
#   'label': 'NFOrce (DE)',
#   'size': 0,
#   'x': 2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F4D03F',
#   'id': 'ViewQwest (SG)',
#   'label': 'ViewQwest (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -5},
#  {'attributes': {},
#   'color': '#48929B',
#   'id': 'GTC (MY)',
#   'label': 'GTC (MY)',
#   'size': 0,
#   'x': -3,
#   'y': -3},
#  {'attributes': {},
#   'color': '#FFB94E',
#   'id': 'Telia Sonera (SG)',
#   'label': 'Telia Sonera (SG)',
#   'size': 0,
#   'x': 5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#1F4788',
#   'id': 'Sunrise (NL)',
#   'label': 'Sunrise (NL)',
#   'size': 0,
#   'x': 1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'PCCW (HK)',
#   'label': 'PCCW (HK)',
#   'size': 0,
#   'x': -5,
#   'y': -4},
#  {'attributes': {},
#   'color': '#03A678',
#   'id': 'Spotify (SG)',
#   'label': 'Spotify (SG)',
#   'size': 0,
#   'x': -2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#4B77BE',
#   'id': '1&1 Internet (UK)',
#   'label': '1&1 Internet (UK)',
#   'size': 0,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#5D8CAE',
#   'id': 'CAT-ISP',
#   'label': 'CAT-ISP',
#   'size': 10,
#   'x': 0,
#   'y': -2},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'Dropbox (UK)',
#   'label': 'Dropbox (UK)',
#   'size': 0,
#   'x': -2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'China Telecom (HK)',
#   'label': 'China Telecom (HK)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#C93756',
#   'id': 'MPT (MM)',
#   'label': 'MPT (MM)',
#   'size': 0,
#   'x': -4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'AT&T (NL)',
#   'label': 'AT&T (NL)',
#   'size': 0,
#   'x': -4,
#   'y': -3},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'TeliaSonera (HK)',
#   'label': 'TeliaSonera (HK)',
#   'size': 0,
#   'x': -4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#4B77BE',
#   'id': 'FASTLY (SG)',
#   'label': 'FASTLY (SG)',
#   'size': 0,
#   'x': 5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'Teliasonera (SG)',
#   'label': 'Teliasonera (SG)',
#   'size': 0,
#   'x': 1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#E68364',
#   'id': 'NHN (SG)',
#   'label': 'NHN (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#F2F1EF',
#   'id': 'PCH (UK)',
#   'label': 'PCH (UK)',
#   'size': 0,
#   'x': 1,
#   'y': -2},
#  {'attributes': {},
#   'color': '#5D8CAE',
#   'id': 'Daliymotion (NL)',
#   'label': 'Daliymotion (NL)',
#   'size': 0,
#   'x': 1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'NetActuate (US)',
#   'label': 'NetActuate (US)',
#   'size': 0,
#   'x': 0,
#   'y': -2},
#  {'attributes': {},
#   'color': '#59ABE3',
#   'id': 'Yahoo (SG)',
#   'label': 'Yahoo (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#FCC9B9',
#   'id': 'SingTel (SG)',
#   'label': 'SingTel (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'PROEN Internet',
#   'label': 'PROEN Internet',
#   'size': 30,
#   'x': 4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#26C281',
#   'id': 'Sunrise (UK)',
#   'label': 'Sunrise (UK)',
#   'size': 0,
#   'x': -1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Valve (SG)',
#   'label': 'Valve (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'LinkedIn (SG)',
#   'label': 'LinkedIn (SG)',
#   'size': 0,
#   'x': -4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'DOSARREST (UK)',
#   'label': 'DOSARREST (UK)',
#   'size': 0,
#   'x': 3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'Hurrican (SG)',
#   'label': 'Hurrican (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'Equinix (FR)',
#   'label': 'Equinix (FR)',
#   'size': 0,
#   'x': 0,
#   'y': -2},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'Cogent (US)',
#   'label': 'Cogent (US)',
#   'size': 0,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#F7CA18',
#   'id': 'AOFEI (SG)',
#   'label': 'AOFEI (SG)',
#   'size': 0,
#   'x': -3,
#   'y': 0},
#  {'attributes': {},
#   'color': '#C93756',
#   'id': 'Telehouse (DE)',
#   'label': 'Telehouse (DE)',
#   'size': 0,
#   'x': -5,
#   'y': -5},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'Telenor (NL)',
#   'label': 'Telenor (NL)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#FFA631',
#   'id': 'Netnod (SG)',
#   'label': 'Netnod (SG)',
#   'size': 0,
#   'x': 4,
#   'y': -4},
#  {'attributes': {},
#   'color': '#FFB61E',
#   'id': 'SIAMDATA',
#   'label': 'SIAMDATA',
#   'size': 10,
#   'x': -3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#407A52',
#   'id': 'WIOCC (UK)',
#   'label': 'WIOCC (UK)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'APPLE (SG)',
#   'label': 'APPLE (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'SOFTBANK (HK)',
#   'label': 'SOFTBANK (HK)',
#   'size': 0,
#   'x': -4,
#   'y': -1},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'NTT APAC (HK)',
#   'label': 'NTT APAC (HK)',
#   'size': 0,
#   'x': 1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#E68364',
#   'id': 'Mainsoft (NL)',
#   'label': 'Mainsoft (NL)',
#   'size': 0,
#   'x': -5,
#   'y': -3},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'SecureAX (SG)',
#   'label': 'SecureAX (SG)',
#   'size': 0,
#   'x': 3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'Planetcom (LA)',
#   'label': 'Planetcom (LA)',
#   'size': 0,
#   'x': 0,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'Core-Backbone (SG)',
#   'label': 'Core-Backbone (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#DB5A6B',
#   'id': 'ColocationIX (UK)',
#   'label': 'ColocationIX (UK)',
#   'size': 0,
#   'x': 5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'CLARA (UK)',
#   'label': 'CLARA (UK)',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'ETL (LA)',
#   'label': 'ETL (LA)',
#   'size': 0,
#   'x': 1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'EdgeCast (SG)',
#   'label': 'EdgeCast (SG)',
#   'size': 0,
#   'x': 0,
#   'y': -4},
#  {'attributes': {},
#   'color': '#9D2933',
#   'id': 'Cogent (FR)',
#   'label': 'Cogent (FR)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'Telenor Globa (MM)',
#   'label': 'Telenor Globa (MM)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#DB5A6B',
#   'id': 'TOT-IIG',
#   'label': 'TOT-IIG',
#   'size': 0,
#   'x': 0,
#   'y': 1},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'GoDaddy (SG)',
#   'label': 'GoDaddy (SG)',
#   'size': 0,
#   'x': -5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#03A678',
#   'id': 'IIJ (SG)',
#   'label': 'IIJ (SG)',
#   'size': 0,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'EZIT (SG)',
#   'label': 'EZIT (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#FFB61E',
#   'id': 'OVH (SG)',
#   'label': 'OVH (SG)',
#   'size': 0,
#   'x': -1,
#   'y': 2},
#  {'attributes': {},
#   'color': '#ABB7B7',
#   'id': 'PLDT (PH)\xa0',
#   'label': 'PLDT (PH)\xa0',
#   'size': 0,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#763568',
#   'id': 'Liquid Telecom (UK)',
#   'label': 'Liquid Telecom (UK)',
#   'size': 0,
#   'x': -1,
#   'y': 0},
#  {'attributes': {},
#   'color': '#757D75',
#   'id': 'Swisscom (SG)',
#   'label': 'Swisscom (SG)',
#   'size': 0,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Smart Infonet',
#   'label': 'Smart Infonet',
#   'size': 0,
#   'x': -3,
#   'y': -2},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'Akamai (HK)',
#   'label': 'Akamai (HK)',
#   'size': 0,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#89C4F4',
#   'id': 'France IX (Fr)',
#   'label': 'France IX (Fr)',
#   'size': 0,
#   'x': -2,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F3C13A',
#   'id': 'PCCW (SG)',
#   'label': 'PCCW (SG)',
#   'size': 0,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'Global Cloud Xchange (SG)',
#   'label': 'Global Cloud Xchange (SG)',
#   'size': 0,
#   'x': 2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#F47983',
#   'id': 'Apple (SG)',
#   'label': 'Apple (SG)',
#   'size': 0,
#   'x': -4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'AS4651',
#   'label': 'AS4651',
#   'size': 0,
#   'x': -1,
#   'y': -4},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'AS45629',
#   'label': 'AS45629',
#   'size': 0,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'AS7568',
#   'label': 'AS7568',
#   'size': 0,
#   'x': 3,
#   'y': 5},
#  {'attributes': {},
#   'color': '#7A942E',
#   'id': 'AS38082',
#   'label': 'AS38082',
#   'size': 0,
#   'x': 0,
#   'y': 1},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'AS132876',
#   'label': 'AS132876',
#   'size': 0,
#   'x': -2,
#   'y': -4},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'AS45458',
#   'label': 'AS45458',
#   'size': 0,
#   'x': 3,
#   'y': -1},
#  {'attributes': {},
#   'color': '#48929B',
#   'id': 'AS24475',
#   'label': 'AS24475',
#   'size': 0,
#   'x': 5,
#   'y': -1}]

# %%
def gen_edges(edge_data):
    edges = []
    for item in edge_data:
        edges.append(new_edge(item[0], {}, item[1], 1))
    return edges

domestic_edges = gen_edges(DOMESTIC_EDGES)
inter_edges = gen_edges(INTER_EDGES)
len(inter_edges)
# Out:
# 637

# %%
def gen_graph(nodes, edges):
    graph = {}
    graph["nodes"] = nodes
    graph["edges"] = edges
    return graph

domestic_graph = gen_graph(domestic_nodes, domestic_edges)
inter_graph = gen_graph(inter_nodes, inter_edges)

# %%
def dump_graph(file_name, graph):
    with open(file_name+".json", 'w') as outfile:
        json.dump(graph, outfile, indent=4, separators=(',', ': '), sort_keys=True)
        
dump_graph(DOMESTIC, domestic_graph)
dump_graph(INTER, inter_graph)
