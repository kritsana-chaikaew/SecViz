# %%
import pandas as pd
import numpy as np
import json
from random import randint
from collections import defaultdict

# %%
FILE_NAME = "2018-07-Domestic-Exchange-Index"

# %%
csv_data = pd.read_csv(FILE_NAME+".csv")

# %%
names = list(set(csv_data["Name"].values))

NODES = defaultdict(set)
for item in csv_data[["ASN", "Name"]].values:
    NODES[item[0]].add(item[1])

# %%
EDGES = [(list(NODES[item[0]])[0], list(NODES[item[1]])[0]) for item in csv_data[["ASN-source", "ASN"]].values]
EDGES
# Out:
# [('CAT-IX (Bangrak/ Nonthaburi)', 'CSL-IX'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'TIG-IX'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'TCCT-IX'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Jastel-IX'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'AWN-IX (SBN)'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'SYMC-IX (Symphony)'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'CAT-ISP'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'INET'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Pacific Internet'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Ji-NET'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'SAMART Infonet'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Triple T Internet'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'KIRZ'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'OTARO'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'ISSP'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'ISSP'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'PROEN'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'True Internet Corporation'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Telstra'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'KSC'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'TOT ISP'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'UIH/ BEENET'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'MILCOM'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Loxley'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'NIPA.CLOUD'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', '101 Global'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'NTT (TH)'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'TOT LLI'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'CAT ON Net'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'ServeNET'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'SIAMDATA'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'TCCT-ISP'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'INOX'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'UniNet'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'ICT MOF'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', 'Metrabyte'),
#  ('CAT-IX (Bangrak/ Nonthaburi)', '1-TO-ALL'),
#  ('CSL-IX', 'Jastel-IX'),
#  ('CSL-IX', 'AWN-IX (SBN)'),
#  ('CSL-IX', 'TIG-IX'),
#  ('CSL-IX', 'TOT-IX'),
#  ('CSL-IX', 'CAT-IX (Bangrak/ Nonthaburi)'),
#  ('CSL-IX', 'TCCT-IX'),
#  ('CSL-IX', 'BB Connect-IX (UIH/BEENET)'),
#  ('CSL-IX', 'BKNIX'),
#  ('CSL-IX', 'DTAC-IX'),
#  ('CSL-IX', 'CS Loxinfo'),
#  ('CSL-IX', 'Triple T Internet'),
#  ('CSL-IX', 'TOT ISP'),
#  ('Jastel-IX', 'CSL-IX'),
#  ('Jastel-IX', 'TOT-IX'),
#  ('Jastel-IX', 'TCCT-IX'),
#  ('Jastel-IX', 'TIG-IX'),
#  ('Jastel-IX', 'CAT-IX (Bangrak/ Nonthaburi)'),
#  ('Jastel-IX', 'DTAC-IX'),
#  ('Jastel-IX', 'AWN-IX (SBN)'),
#  ('Jastel-IX', 'Triple T Internet'),
#  ('Jastel-IX', 'Ji-NET'),
#  ('Jastel-IX', '2S1N'),
#  ('Jastel-IX', 'INET'),
#  ('Jastel-IX', 'TOT ISP'),
#  ('Jastel-IX', 'PROEN'),
#  ('Jastel-IX', 'NIPA.CLOUD'),
#  ('Jastel-IX', 'PTT ICT'),
#  ('Jastel-IX', 'SAMART Infonet'),
#  ('Jastel-IX', 'NTT (TH)'),
#  ('AWN-IX (SBN)', 'CSL-IX'),
#  ('AWN-IX (SBN)', 'TIG-IX'),
#  ('AWN-IX (SBN)', 'CAT-IX (Bangrak/ Nonthaburi)'),
#  ('AWN-IX (SBN)', 'DTAC-IX'),
#  ('AWN-IX (SBN)', 'Jastel-IX'),
#  ('AWN-IX (SBN)', 'TOT-IX'),
#  ('AWN-IX (SBN)', 'TCCT-IX'),
#  ('AWN-IX (SBN)', 'Triple T Internet'),
#  ('AWN-IX (SBN)', 'AWN-IX (SBN)'),
#  ('AWN-IX (SBN)', 'INET'),
#  ('AWN-IX (SBN)', 'PROEN'),
#  ('AWN-IX (SBN)', 'NIPA.CLOUD'),
#  ('AWN-IX (SBN)', 'PTT ICT'),
#  ('AWN-IX (SBN)', 'OTARO'),
#  ('AWN-IX (SBN)', 'TOT ISP'),
#  ('SYMC-IX', 'DTAC-IX'),
#  ('SYMC-IX', 'TIG-IX'),
#  ('SYMC-IX', 'SYMC-IX (Symphony)'),
#  ('SYMC-IX', 'AWN-IX (SBN)'),
#  ('SYMC-IX', 'A-Net'),
#  ('SYMC-IX', 'PROEN'),
#  ('SYMC-IX', 'Loxley'),
#  ('SYMC-IX', 'UniNet'),
#  ('TCCT-IX', 'TOT-IX'),
#  ('TCCT-IX', 'CAT-IX (Bangrak/ Nonthaburi)'),
#  ('TCCT-IX', 'Jastel-IX'),
#  ('TCCT-IX', 'CSL-IX'),
#  ('TCCT-IX', 'TIG-IX'),
#  ('TCCT-IX', 'DTAC-IX'),
#  ('TCCT-IX', 'BKNIX'),
#  ('TCCT-IX', 'AWN-IX (SBN)'),
#  ('TCCT-IX', 'Dots Solutions'),
#  ('TCCT-IX', 'INET'),
#  ('TCCT-IX', 'OTARO'),
#  ('TCCT-IX', 'TCCT-ISP'),
#  ('TCCT-IX', 'TOT ISP'),
#  ('TIG-IX', 'CAT-IX (Bangrak/ Nonthaburi)'),
#  ('TIG-IX', 'TOT-IX'),
#  ('TIG-IX', 'CSL-IX'),
#  ('TIG-IX', 'AWN-IX (SBN)'),
#  ('TIG-IX', 'Jastel-IX'),
#  ('TIG-IX', 'TCCT-IX'),
#  ('TIG-IX', 'KSC'),
#  ('TIG-IX', 'True Internet Corporation'),
#  ('TIG-IX', 'NTT (TH)'),
#  ('TIG-IX', 'NIPA.CLOUD'),
#  ('TIG-IX', 'KIRZ'),
#  ('TIG-IX', 'PROEN'),
#  ('TIG-IX', 'ISSP'),
#  ('TIG-IX', 'INET'),
#  ('TIG-IX', 'A-Net'),
#  ('TIG-IX', 'UIH/ BEENET'),
#  ('TIG-IX', 'Siam Data'),
#  ('TIG-IX', 'SYMC-IX'),
#  ('TOT-IX', 'CSL-IX'),
#  ('TOT-IX', 'Jastel-IX'),
#  ('TOT-IX', 'TIG-IX'),
#  ('TOT-IX', 'TCCT-IX'),
#  ('TOT-IX', 'MOE'),
#  ('TOT-IX', 'TOT LLI'),
#  ('TOT-IX', 'NIPA.CLOUD'),
#  ('TOT-IX', 'KSC'),
#  ('TOT-IX', 'INET'),
#  ('TOT-IX', 'PROEN'),
#  ('TOT-IX', 'TOT ISP'),
#  ('TOT-IX', 'OTARO'),
#  ('TOT-IX', 'KIRZ'),
#  ('TOT-IX', 'SIAMDATA'),
#  ('TOT-IX', 'SYMC-IX (Symphony)'),
#  ('TOT-IX', 'CAT-ISP'),
#  ('TOT-IX', 'UIH/ BEENET'),
#  ('TOT-IX', 'POP-IDC'),
#  ('TOT-IX', 'AWN-IX (SBN)'),
#  ('TOT-IX', 'TOT-IDC'),
#  ('TOT-IX', 'GIN'),
#  ('DTAC-IX', 'CSL-IX'),
#  ('DTAC-IX', 'Jastel-IX'),
#  ('DTAC-IX', 'SYMC-IX (Symphony)'),
#  ('DTAC-IX', 'AWN-IX (SBN)'),
#  ('DTAC-IX', 'BKNIX'),
#  ('DTAC-IX', 'TCCT-IX'),
#  ('DTAC-IX', 'Dtac Trinet'),
#  ('DTAC-IX', 'INET'),
#  ('BKNIX', 'BB Connect'),
#  ('BKNIX', 'TCCT-IX'),
#  ('BKNIX', 'DTAC-IX'),
#  ('BKNIX', 'CSL-IX'),
#  ('BKNIX', 'Triple T Internet'),
#  ('BKNIX', 'INET'),
#  ('BKNIX', 'KIRZ'),
#  ('BKNIX', 'NTT (TH)'),
#  ('BKNIX', 'UniNet'),
#  ('BKNIX', 'EGA'),
#  ('BKNIX', 'True Internet Corporation'),
#  ('BKNIX', 'UIH/ BEENET'),
#  ('BKNIX', 'AIT'),
#  ('BKNIX', 'INOX')]

# %%
def new_node(color, label, attributes, x, y, _id):
    node = {}
    node["color"] = color
    node["label"] = label
    node["attributes"] = attributes
    node["y"] = y
    node["x"] = x
    node["id"] = _id
    node["size"] = len([1 for pair in EDGES if label in pair])
    return node

# %%
def new_edge(sourceID, attributes, targetID, size):
    edge = {}
    edge["sourceID"] = sourceID
    edge["attributes"] = attributes
    edge["targetID"] = targetID
    edge["size"] = size
    return edge

# %%
colors = [
"#C91F37",
"#DC3023",
"#9D2933",
"#CF000F",
"#E68364",
"#F22613",
"#CF3A24",
"#C3272B",
"#8F1D21",
"#D24D57",
"#F08F907",
"#F47983",
"#DB5A6B",
"#C93756",
"#FCC9B9",
"#FFB3A7",
"#F62459",
"#F58F84",
"#875F9A",
"#5D3F6A",
"#89729E",
"#763568",
"#8D608C",
"#A87CA0",
"#5B3256",
"#BF55EC",
"#8E44AD",
"#9B59B6",
"#BE90D4",
"#4D8FAC",
"#5D8CAE",
"#22A7F0",
"#19B5FE",
"#59ABE3",
"#48929B",
"#317589",
"#89C4F4",
"#4B77BE",
"#1F4788",
"#003171",
"#044F67",
"#264348",
"#7A942E",
"#8DB255",
"#5B8930",
"#6B9362",
"#407A52",
"#006442",
"#87D37C",
"#26A65B",
"#26C281",
"#049372",
"#2ABB9B",
"#16A085",
"#36D7B7",
"#03A678",
"#4DAF7C",
"#D9B611",
"#F3C13A",
"#F7CA18",
"#E2B13C",
"#A17917",
"#F5D76E",
"#F4D03F",
"#FFA400",
"#E08A1E",
"#FFB61E",
"#FAA945",
"#FFA631",
"#FFB94E",
"#E29C45",
"#F9690E",
"#CA6924",
"#F5AB35",
"#BFBFBF",
"#F2F1EF",
"#BDC3C7",
"#ECF0F1",
"#D2D7D3",
"#757D75",
"#EEEEEE",
"#ABB7B7",
"#6C7A89",
"#95A5A6"]
colors_count = len(colors)

# %%
nodes = []
for node in names:
    nodes.append(
        new_node(
            color=colors[randint(0, colors_count-1)], 
            label=node, 
            attributes={}, 
            x=randint(-5, 5), 
            y=randint(-5, 5), 
            _id=node
        )
    )
nodes
# Out:
# [{'attributes': {},
#   'color': '#F4D03F',
#   'id': 'SIAMDATA',
#   'label': 'SIAMDATA',
#   'size': 20,
#   'x': 3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'ICT MOF',
#   'label': 'ICT MOF',
#   'size': 10,
#   'x': 3,
#   'y': 0},
#  {'attributes': {},
#   'color': '#9B59B6',
#   'id': 'TCCT-IX',
#   'label': 'TCCT-IX',
#   'size': 210,
#   'x': 2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#59ABE3',
#   'id': 'Telstra',
#   'label': 'Telstra',
#   'size': 10,
#   'x': 2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'CS Loxinfo',
#   'label': 'CS Loxinfo',
#   'size': 10,
#   'x': 3,
#   'y': -5},
#  {'attributes': {},
#   'color': '#044F67',
#   'id': '1-TO-ALL',
#   'label': '1-TO-ALL',
#   'size': 10,
#   'x': 3,
#   'y': 1},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'Symphony-ISP',
#   'label': 'Symphony-ISP',
#   'size': 0,
#   'x': 5,
#   'y': 4},
#  {'attributes': {},
#   'color': '#95A5A6',
#   'id': 'TOT ISP',
#   'label': 'TOT ISP',
#   'size': 60,
#   'x': 1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Triple T Internet',
#   'label': 'Triple T Internet',
#   'size': 50,
#   'x': 2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#22A7F0',
#   'id': 'PTT ICT',
#   'label': 'PTT ICT',
#   'size': 20,
#   'x': 5,
#   'y': 2},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'UIH/ BEENET',
#   'label': 'UIH/ BEENET',
#   'size': 40,
#   'x': 0,
#   'y': 3},
#  {'attributes': {},
#   'color': '#BF55EC',
#   'id': 'UIH /BEENET',
#   'label': 'UIH /BEENET',
#   'size': 0,
#   'x': -2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#26C281',
#   'id': 'DTAC-IX',
#   'label': 'DTAC-IX',
#   'size': 140,
#   'x': 2,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'Dtac Trinet',
#   'label': 'Dtac Trinet',
#   'size': 10,
#   'x': 3,
#   'y': -4},
#  {'attributes': {},
#   'color': '#049372',
#   'id': 'INET',
#   'label': 'INET',
#   'size': 80,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'A-Net',
#   'label': 'A-Net',
#   'size': 20,
#   'x': 4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'KIRZ',
#   'label': 'KIRZ',
#   'size': 40,
#   'x': -5,
#   'y': 0},
#  {'attributes': {},
#   'color': '#6C7A89',
#   'id': 'ISSP',
#   'label': 'ISSP',
#   'size': 30,
#   'x': -2,
#   'y': 1},
#  {'attributes': {},
#   'color': '#DB5A6B',
#   'id': 'AIT',
#   'label': 'AIT',
#   'size': 10,
#   'x': -4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'True Internet Corporation',
#   'label': 'True Internet Corporation',
#   'size': 30,
#   'x': 4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#95A5A6',
#   'id': 'ServeNET',
#   'label': 'ServeNET',
#   'size': 10,
#   'x': -5,
#   'y': -4},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'CSL-IX',
#   'label': 'CSL-IX',
#   'size': 200,
#   'x': 3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#049372',
#   'id': '2S1N',
#   'label': '2S1N',
#   'size': 10,
#   'x': 0,
#   'y': 4},
#  {'attributes': {},
#   'color': '#317589',
#   'id': 'TOT-IX',
#   'label': 'TOT-IX',
#   'size': 260,
#   'x': -2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#5D3F6A',
#   'id': 'INOX',
#   'label': 'INOX',
#   'size': 20,
#   'x': 5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#8D608C',
#   'id': 'Jastel-IX',
#   'label': 'Jastel-IX',
#   'size': 240,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'UIH (Beenet)',
#   'label': 'UIH (Beenet)',
#   'size': 0,
#   'x': -4,
#   'y': 3},
#  {'attributes': {},
#   'color': '#C3272B',
#   'id': 'SAMART Infonet',
#   'label': 'SAMART Infonet',
#   'size': 20,
#   'x': 4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#36D7B7',
#   'id': 'SYMC-IX (Symphony)',
#   'label': 'SYMC-IX (Symphony)',
#   'size': 40,
#   'x': 4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#F08F907',
#   'id': 'TCCT-ISP',
#   'label': 'TCCT-ISP',
#   'size': 20,
#   'x': 2,
#   'y': 1},
#  {'attributes': {},
#   'color': '#89729E',
#   'id': 'JasTel-IX',
#   'label': 'JasTel-IX',
#   'size': 0,
#   'x': 0,
#   'y': -1},
#  {'attributes': {},
#   'color': '#FCC9B9',
#   'id': 'Siam Data',
#   'label': 'Siam Data',
#   'size': 10,
#   'x': 4,
#   'y': 1},
#  {'attributes': {},
#   'color': '#FFB3A7',
#   'id': 'EGA',
#   'label': 'EGA',
#   'size': 10,
#   'x': 1,
#   'y': -3},
#  {'attributes': {},
#   'color': '#757D75',
#   'id': 'BKNIX',
#   'label': 'BKNIX',
#   'size': 170,
#   'x': 2,
#   'y': 5},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'AWN-ISP (SBN)',
#   'label': 'AWN-ISP (SBN)',
#   'size': 0,
#   'x': 2,
#   'y': 5},
#  {'attributes': {},
#   'color': '#26A65B',
#   'id': 'CAT ON Net',
#   'label': 'CAT ON Net',
#   'size': 10,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#D2D7D3',
#   'id': '101 Global',
#   'label': '101 Global',
#   'size': 10,
#   'x': -1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#19B5FE',
#   'id': 'AWN-IX (SBN)',
#   'label': 'AWN-IX (SBN)',
#   'size': 230,
#   'x': -3,
#   'y': 4},
#  {'attributes': {},
#   'color': '#CF3A24',
#   'id': 'CAT-ISP',
#   'label': 'CAT-ISP',
#   'size': 20,
#   'x': -4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#F3C13A',
#   'id': 'CAT-IX (Bangrak/ Nonthaburi)',
#   'label': 'CAT-IX (Bangrak/ Nonthaburi)',
#   'size': 420,
#   'x': 1,
#   'y': -5},
#  {'attributes': {},
#   'color': '#CF000F',
#   'id': 'Pacific Internet',
#   'label': 'Pacific Internet',
#   'size': 10,
#   'x': 0,
#   'y': 3},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Metrabyte',
#   'label': 'Metrabyte',
#   'size': 10,
#   'x': -5,
#   'y': -4},
#  {'attributes': {},
#   'color': '#006442',
#   'id': 'Ji-NET',
#   'label': 'Ji-NET',
#   'size': 20,
#   'x': 1,
#   'y': 1},
#  {'attributes': {},
#   'color': '#E29C45',
#   'id': 'BB Connect',
#   'label': 'BB Connect',
#   'size': 10,
#   'x': -4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'PROEN',
#   'label': 'PROEN',
#   'size': 60,
#   'x': 2,
#   'y': -3},
#  {'attributes': {},
#   'color': '#A87CA0',
#   'id': 'TOT LLI',
#   'label': 'TOT LLI',
#   'size': 20,
#   'x': 4,
#   'y': 4},
#  {'attributes': {},
#   'color': '#16A085',
#   'id': 'TIG-IX (TRUE)',
#   'label': 'TIG-IX (TRUE)',
#   'size': 0,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#EEEEEE',
#   'id': 'Loxley',
#   'label': 'Loxley',
#   'size': 20,
#   'x': -4,
#   'y': 0},
#  {'attributes': {},
#   'color': '#003171',
#   'id': 'KSC',
#   'label': 'KSC',
#   'size': 30,
#   'x': 5,
#   'y': 1},
#  {'attributes': {},
#   'color': '#E08A1E',
#   'id': 'OTARO',
#   'label': 'OTARO',
#   'size': 40,
#   'x': -1,
#   'y': -1},
#  {'attributes': {},
#   'color': '#95A5A6',
#   'id': 'TIG-IX',
#   'label': 'TIG-IX',
#   'size': 250,
#   'x': 1,
#   'y': 5},
#  {'attributes': {},
#   'color': '#875F9A',
#   'id': 'Dots Solutions',
#   'label': 'Dots Solutions',
#   'size': 10,
#   'x': 4,
#   'y': 5},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'TOT-IDC',
#   'label': 'TOT-IDC',
#   'size': 10,
#   'x': 4,
#   'y': 2},
#  {'attributes': {},
#   'color': '#89C4F4',
#   'id': 'BB Connect-IX (UIH/BEENET)',
#   'label': 'BB Connect-IX (UIH/BEENET)',
#   'size': 10,
#   'x': 4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#E08A1E',
#   'id': 'UniNet',
#   'label': 'UniNet',
#   'size': 30,
#   'x': 2,
#   'y': 0},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'CAT-IX (Bangrak/Nonthaburi)',
#   'label': 'CAT-IX (Bangrak/Nonthaburi)',
#   'size': 0,
#   'x': 2,
#   'y': -2},
#  {'attributes': {},
#   'color': '#8D608C',
#   'id': 'NIPA.CLOUD',
#   'label': 'NIPA.CLOUD',
#   'size': 50,
#   'x': 2,
#   'y': 1},
#  {'attributes': {},
#   'color': '#E08A1E',
#   'id': 'MILCOM',
#   'label': 'MILCOM',
#   'size': 10,
#   'x': -4,
#   'y': -3},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'UIH (BeeNet)',
#   'label': 'UIH (BeeNet)',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#F22613',
#   'id': 'SYMC-IX',
#   'label': 'SYMC-IX',
#   'size': 90,
#   'x': -3,
#   'y': 2},
#  {'attributes': {},
#   'color': '#FFA631',
#   'id': 'Triple T Internet/ Triple T Broadband',
#   'label': 'Triple T Internet/ Triple T Broadband',
#   'size': 0,
#   'x': 5,
#   'y': 5},
#  {'attributes': {},
#   'color': '#CA6924',
#   'id': 'NTT (TH)',
#   'label': 'NTT (TH)',
#   'size': 40,
#   'x': -2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#ECF0F1',
#   'id': 'POP-IDC',
#   'label': 'POP-IDC',
#   'size': 10,
#   'x': 2,
#   'y': -1},
#  {'attributes': {},
#   'color': '#C91F37',
#   'id': 'GIN',
#   'label': 'GIN',
#   'size': 10,
#   'x': -1,
#   'y': 4},
#  {'attributes': {},
#   'color': '#2ABB9B',
#   'id': 'TOT-ISP',
#   'label': 'TOT-ISP',
#   'size': 0,
#   'x': 5,
#   'y': 3},
#  {'attributes': {},
#   'color': '#F62459',
#   'id': 'PROEN Internet',
#   'label': 'PROEN Internet',
#   'size': 0,
#   'x': 0,
#   'y': 5},
#  {'attributes': {},
#   'color': '#D9B611',
#   'id': 'AWN-IX',
#   'label': 'AWN-IX',
#   'size': 0,
#   'x': -4,
#   'y': -2},
#  {'attributes': {},
#   'color': '#F58F84',
#   'id': 'MOE',
#   'label': 'MOE',
#   'size': 10,
#   'x': 1,
#   'y': 0}]

# %%
edges = []
for item in EDGES:
    edges.append(new_edge(item[0], {}, item[1], 1))

# %%
graph = {}
graph["nodes"] = nodes
graph["edges"] = edges

# %%
with open(FILE_NAME+".json", 'w') as outfile:
    json.dump(graph, outfile, indent=4, separators=(',', ': '), sort_keys=True)
